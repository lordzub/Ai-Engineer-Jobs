# %%
import os
import requests
from supabase import create_client, Client
from dotenv import load_dotenv
import time

# --- 1. SETUP ---
load_dotenv()

# Connect to Supabase
SUPABASE_URL = os.environ.get("SUPABASE_URL")
SUPABASE_KEY = os.environ.get("SUPABASE_KEY")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

# Bright Data Config
BRIGHTDATA_ENDPOINT = os.environ.get("BRIGHTDATA_ENDPOINT")
BRIGHTDATA_HEADERS = {
    'Authorization': f'Bearer {os.environ.get("BRIGHTDATA_API_KEY")}'
}

# --- 2. BRIGHT DATA API CALL ---
def get_jobs_from_brightdata(role, city):
    """
    Calls the Bright Data scraper API for a specific role and city.
    """
    print(f"--- Fetching jobs for {role} in {city} ---")
    
    # This payload format depends on your specific Bright Data scraper
    payload = {
        'keyword': role,
        'location': city,
        "country":"US",
        "time_range":"Past week"
    }
    
    try:
        # Using a POST request as is common for scraper IDEs
        response = requests.post(
            BRIGHTDATA_ENDPOINT,
            json=payload,
            headers=BRIGHTDATA_HEADERS
        )
        response.raise_for_status() # Raises an error for bad responses (4xx or 5xx)
        
        # The structure of response.json() will depend on YOUR scraper's output
        # For this example, we assume it returns a list of job objects
        jobs = response.json()
        print(f"Found {len(jobs)} jobs.")
        return jobs
        
    except requests.exceptions.RequestException as e:
        print(f"Error calling Bright Data: {e}")
        return []

# --- 3. SUPABASE DATA HANDLING ---
def get_or_create_company(company_name, company_website=None, logo_url=None):
    """
    Intelligently gets a company ID. If the company doesn't exist, it creates it.
    This is an "upsert" (update or insert).
    """
    
    # .upsert() is perfect for this.
    # It will find a company with that name, or create a new one.
    data, count = supabase.table('companies').upsert(
        {
            'name': company_name,
            'website_url': company_website,
            'logo_url': logo_url
        },
        on_conflict='name' # This tells Supabase to match based on the 'name' column
    ).execute()
    
    # Return the ID of the company (whether new or existing)
    return data[0]['id']

def insert_job(job, company_id):
    """
    Inserts a single job into the 'jobs' table,
    first checking if it already exists based on the 'apply_url'.
    """
    try:
        # Check if job already exists (based on our unique constraint)
        existing = supabase.table('jobs').select('id').eq('apply_url', job['apply_url']).execute()
        
        if existing.data:
            print(f"Skipping duplicate: {job['title']}")
            return

        # Prepare the job record for insertion
        job_record = {
            'title': job['title'],
            'description': job['description'],
            'company_id': company_id,
            'location_name': job.get('location', 'N/A'), # Use .get() for safety
            'location_type': job.get('location_type', 'On-Site'),
            'apply_url': job['apply_url'],
            'posted_at': job.get('posted_at_timestamp', 'now()'),
            'source': 'BrightData',
            'is_paid': False,
            'is_featured': False
        }
        
        # Insert the new job
        supabase.table('jobs').insert(job_record).execute()
        print(f"Successfully inserted: {job['title']}")

    except Exception as e:
        print(f"Error inserting job {job.get('title')}: {e}")

# --- 4. MAIN SCRIPT LOGIC ---
def main():
    """
    Main function to run the backfill process.
    """
    
    # START SMALL (as you suggested)
    # This list will grow to 100s of combinations
    targets = [
        # California (Bay Area)
        ("AI Engineer", "San Francisco, CA"),
        ("AI Engineer", "San Jose, CA"),
        ("AI Engineer", "Palo Alto, CA"),
        ("AI Engineer", "Mountain View, CA"),
        ("AI Engineer", "Oakland, CA"),
        ("AI Engineer", "Santa Clara, CA"),
        ("AI Engineer", "Sunnyvale, CA"),
        # California (SoCal)
        ("AI Engineer", "Los Angeles, CA"),
        ("AI Engineer", "San Diego, CA"),
        # Washington
        ("AI Engineer", "Seattle, WA"),
        ("AI Engineer", "Bellevue, WA"),
        ("AI Engineer", "Redmond, WA"),
        # Massachusetts
        ("AI Engineer", "Boston, MA"),
        ("AI Engineer", "Cambridge, MA"),
        ("AI Engineer","Somerville, MA"),
        # DC Metro
        ("AI Engineer", "Washington, D.C."),
        ("AI Engineer", "Arlington, VA"),
        # Maryland
        ("AI Engineer", "Baltimore, MD"),
        ("AI Engineer", "Rockville, MD"),
        ("AI Engineer", "Bethesda, MD"),
        ("AI Engineer", "Gaithersburg, MD"),
        ("AI Engineer", "Columbia, MD"),
        ("AI Engineer", "Silver Spring, MD"),
    ]
    
    for role, city in targets:
        # 1. Get data from Bright Data
        # IMPORTANT: Bright Data's response format must be mapped here.
        # We assume `jobs` is a list of dicts like:
        # { 'title': '...', 'company_name': '...', 'description': '...', 'apply_url': '...', ... }
        jobs = get_jobs_from_brightdata(role, city)
        
        if not jobs:
            continue
            
        for job in jobs:
            # 2. Get or create the company
            # You must map your Bright Data fields to these
            company_id = get_or_create_company(
                job['company_name'],
                job.get('company_website'),
                job.get('company_logo')
            )
            
            # 3. Insert the job
            insert_job(job, company_id)
            
            # Rate limit ourselves to be kind to Supabase
            time.sleep(0.5) 
            
    print("--- Backfill complete ---")

if __name__ == "__main__":
    main()

# %%
import os
import requests
import pandas as pd
from supabase import create_client, Client
from dotenv import load_dotenv
import time
import json  # <-- 1. IMPORT THE JSON LIBRARY

# --- 1. SETUP ---
# Make sure you have:
# pip install pandas supabase-client python-dotenv requests

load_dotenv()

# --- Supabase Credentials ---
SUPABASE_URL = os.environ.get("SUPABASE_URL")
SUPABASE_KEY = os.environ.get("SUPABASE_KEY")
if not SUPABASE_URL or not SUPABASE_KEY:
    raise EnvironmentError("Supabase credentials not found in .env file")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

# --- Bright Data Credentials ---
BRIGHTDATA_API_KEY = os.environ.get("BRIGHTDATA_API_KEY")
if not BRIGHTDATA_API_KEY:
    raise EnvironmentError("Bright Data API key not found in .env file")

# --- FILE & API CONFIG ---
LOG_FILE = 'api_logs_2025-11-16_14-22-09.csv' # The log file you uploaded

# This endpoint is not used, but left here from your script
DOWNLOAD_ENDPOINT = "https://api.brightdata.com/datasets/v3/snapshot/"

BRIGHTDATA_HEADERS = {
    'Authorization': f'Bearer {BRIGHTDATA_API_KEY}'
}

# --- 2. SUPABASE HELPER FUNCTIONS ---
def get_or_create_company(company_name, company_website=None, logo_url=None):
    clean_name = str(company_name).strip()
    if not clean_name:
        print("Skipping company: company_name is empty.")
        return None

    try:
        company_data = {'name': clean_name}
        if company_website: company_data['website_url'] = company_website
        if logo_url: company_data['logo_url'] = logo_url

        print(company_data)

        # FIX: capture proper response object
        response = supabase.table('companies').upsert(
            [company_data],
            on_conflict='name'
        ).execute()

        rows = response.data   # <-- This is always a list

        if rows and 'id' in rows[0]:
            return rows[0]['id']

        # fallback if no ID returned
        response = supabase.table('companies').select('id').eq('name', clean_name).execute()

        rows = response.data
        if rows and 'id' in rows[0]:
            return rows[0]['id']

        print(f"❌ Error: Could not get or create company ID for {clean_name}")
        return None

    except Exception as e:
        print(f"❌ Error upserting company {clean_name}: {e}")
        return None

def insert_job(job_row, company_id):
    """
    Upserts a single job (as a dict) into the 'jobs' table.
    Uses 'url' as the unique key.
    """
    title = job_row.get('job_title', 'No Title Provided')
    
    try:
        apply_url = job_row.get('apply_link') or job_row.get('url')  
        
        if not apply_url:
            print(f"Skipping job ({title}): 'url' field is missing.")
            return

        # --- Parse Location Type ---
        parsed_location_type = 'On-Site' # Default
        title_lower = title.lower()
        summary_lower = job_row.get('job_summary', '').lower()
        job_location_lower = job_row.get('job_location', '').lower()

        if 'remote' in title_lower or 'remote' in summary_lower or 'remote' in job_location_lower:
            parsed_location_type = 'Remote'
        elif 'hybrid' in title_lower or 'hybrid' in summary_lower or 'hybrid' in job_location_lower:
            parsed_location_type = 'Hybrid'
            
        # --- Parse Salary Data ---
        salary_data = job_row.get('base_salary')
        salary_min = None
        salary_max = None
        salary_currency = None
        salary_period = None

        if isinstance(salary_data, dict):
            salary_min = salary_data.get('min_amount')
            salary_max = salary_data.get('max_amount')
            salary_currency = salary_data.get('currency')
            salary_period = salary_data.get('payment_period')

        # --- Build final job record ---
        job_record = {
            'title': title,
            'description': job_row.get('job_summary', 'No Description'),
            'company_id': company_id,
            'location_name': job_row.get('job_location', 'N/A'),
            'location_type': parsed_location_type,
            'employment_type': job_row.get('job_employment_type'),
            'apply_url': apply_url,
            'posted_at': job_row.get('job_posted_date', 'now()'),
            'source': 'BrightData',
            'is_paid': False,
            'is_featured': False,
            'salary_min': salary_min,
            'salary_max': salary_max,
            'salary_currency': salary_currency,
            'salary_period': salary_period
        }
        
        # --- Use upsert for efficiency ---
        data, count = supabase.table('jobs').upsert(
            job_record,
            on_conflict='apply_url' # Your unique constraint name
        ).execute()

        # Check if a new record was actually inserted
        if data and data[0] and len(data[0]) > 1:
             print(f"✅ Successfully inserted: {title}")
        else:
             print(f"Skipping duplicate: {title}")

    except Exception as e:
        print(f"❌ Error upserting job {title}: {e}")

# --- 3. MAIN SCRIPT LOGIC ---
def main():
    """
    Main function to read the log, download data, and populate the DB.
    """
    print("--- Starting Bright Data Log Processor ---")
    
    try:
        df_logs = pd.read_csv(LOG_FILE)
    except FileNotFoundError:
        print(f"ERROR: Log file not found: {LOG_FILE}")
        return
    except Exception as e:
        print(f"ERROR: Could not read log file: {e}")
        return

    # Filter for successful runs with data
    successful_runs = df_logs[
        (df_logs['status'] == 'ready') &  
        (df_logs['dataset_size'] > 0)
    ]

    print(f"Found {len(successful_runs)} successful snapshots to process.")
    
    # Process one by one
    for snapshot_id in successful_runs['id']:
        print(f"\n--- Processing snapshot: {snapshot_id} ---")
        
        # We don't need params, since the ID is in the URL
        try:
            # Use the URL structure from your script
            url = f"https://api.brightdata.com/datasets/v3/snapshot/{snapshot_id}"
            response = requests.get(
                url,
                headers=BRIGHTDATA_HEADERS,
                timeout=60 # Add a timeout
            )
            response.raise_for_status() # Raise HTTP errors
            
            # --- ⬇️ 2. FIX: PARSE THE NDJSON (NEWLINE-DELIMITED JSON) ---
            print(f"Successfully downloaded {snapshot_id}. Parsing NDJSON...")
            
            raw_text = response.text
            jobs_data = [] # This will be our list of *dictionaries*
            
            # STAGE 1: Parse all lines into a list of dictionaries
            for line in raw_text.splitlines():
                if not line.strip(): # Skip empty lines
                    continue
                try:
                    job_object = json.loads(line) # Parse the *string* line into a *dict*
                    jobs_data.append(job_object)   # Add the *dict* to our list
                except json.JSONDecodeError as e:
                    print(f"Skipping malformed line: {e}")
            
            print(f"Successfully parsed {len(jobs_data)} JSON objects.")
            # --- END OF FIX ---

        except requests.exceptions.RequestException as e:
            print(f"Failed to download {snapshot_id}: {e}")
            continue 
        
        # --- STAGE 2: PROCESS THE PARSED DATA ---
        print(f"Processing {len(jobs_data)} job records...")
        
        for job_row in jobs_data:
            # Now this check will work correctly
            if not isinstance(job_row, dict):
                print(f"Skipping record: not a dictionary. Data: {job_row}")
                continue
            
            # This check will correctly filter out error objects
            if job_row.get('error'):
                print(f"Skipping record: it's an error log ({job_row.get('error_code')})")
                continue

            company_name = job_row.get('company_name')
            apply_url = job_row.get('url')
            print(company_name, apply_url)
            if not company_name or not apply_url:
                print("Skipping job: missing company name or URL.")
                continue

            # 3. GET/CREATE COMPANY
            company_id = get_or_create_company(
                company_name,
                job_row.get('company_url'),
                job_row.get('company_logo')
            )
            
            if not company_id:
                print(f"Skipping job, could not create company: {company_name}")
                continue
            
            # 4. INSERT JOB
            insert_job(job_row, company_id)
            time.sleep(0.05) # Be polite to Supabase API
            
        print(f"Finished processing snapshot {snapshot_id}.")

    print("\n--- All snapshots processed. ---")

# %%
main()
# Out:
# --- Starting Bright Data Log Processor ---
# Found 35 successful snapshots to process.
#
# --- Processing snapshot: sd_mi1sz8gw2emnoznnzx ---
# Successfully downloaded sd_mi1sz8gw2emnoznnzx. Parsing NDJSON...
# Successfully parsed 101 JSON objects.
# Processing 101 job records...
# Skipping record: it's an error log (aborted_page)
# TikTok https://www.linkedin.com/jobs/view/machine-learning-engineer-graduate-ads-core-global-2025-start-bs-ms-at-tiktok-4076508901?_l=en
# {'name': 'TikTok', 'website_url': 'https://www.linkedin.com/company/tiktok?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQHYzDOZhwEZ7Q/company-logo_100_100/B56Zl_CaXSIAAU-/0/1758772964879/tiktok_logo?e=2147483647&v=beta&t=pOXL9bnyBOPMlI34LzNiPIxaX9lk7ry0r40olePnSGE'}
# ✅ Successfully inserted: Machine Learning Engineer Graduate (Ads Core Global) - 2025 Start (BS/MS)
# Take2 Consulting, LLC https://www.linkedin.com/jobs/view/artificial-intelligence-engineer-at-take2-consulting-llc-4335925609?_l=en
# {'name': 'Take2 Consulting, LLC', 'website_url': 'https://www.linkedin.com/company/take2-consulting-llc?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C4E0BAQF5ArcTNtbLwQ/company-logo_100_100/company-logo_100_100/0/1631346251031?e=2147483647&v=beta&t=VJbU48w0SbO4gY7z3O2drljopkZPenvpSHIDRyrbvoQ'}
# ✅ Successfully inserted: Artificial Intelligence Engineer
# Catalyst Labs https://www.linkedin.com/jobs/view/ml-engineer-at-catalyst-labs-4322670456?_l=en
# {'name': 'Catalyst Labs', 'website_url': 'https://www.linkedin.com/company/catalystlabssl?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQEcF6HUlv4_nw/company-logo_100_100/company-logo_100_100/0/1710726945004/catalystlabssl_logo?e=2147483647&v=beta&t=QW4EEq6JmkM9VMjOTAVo01G0fYtmuAOXFkAjAX3jP7o'}
# ✅ Successfully inserted: ML Engineer
# GEICO https://www.linkedin.com/jobs/view/software-engineer-ai-ml-infra-at-geico-4322565074?_l=en
# {'name': 'GEICO', 'website_url': 'https://www.linkedin.com/company/geico?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGF25KGwu06pw/company-logo_100_100/company-logo_100_100/0/1728937460623/geico_logo?e=2147483647&v=beta&t=k1CcvYdPW230WUD4VRffwKd4tGPKmYocmWoWgnVJfY4'}
# ✅ Successfully inserted: Software Engineer - AI/ML Infra
# Code Metal https://www.linkedin.com/jobs/view/ai-research-engineer-at-code-metal-4335766688?_l=en
# {'name': 'Code Metal', 'website_url': 'https://www.linkedin.com/company/code-metal?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFUxiyP5PsI-g/company-logo_100_100/B56Zp5rl1EJwAU-/0/1762978061970/code_metal_logo?e=2147483647&v=beta&t=ry1AQzRQ7oqFP7H1m5NwIdtWeLDRPyZ94C7e9S7_7EA'}
# ✅ Successfully inserted: AI Research Engineer
# Discover International https://www.linkedin.com/jobs/view/senior-ml-research-engineer-at-discover-international-4340044179?_l=en
# {'name': 'Discover International', 'website_url': 'https://uk.linkedin.com/company/discoverintl?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQHq8vTakEjAIg/company-logo_100_100/B4EZfLTuAwG4AQ-/0/1751462633946/discoverintl_logo?e=2147483647&v=beta&t=X5aW9K_4UdPJx8r7Q0PyNFb8fMJ4f6AiT0OyroCmRc0'}
# ✅ Successfully inserted: Senior ML Research Engineer
# RecruitSeq https://www.linkedin.com/jobs/view/artificial-intelligence-engineer-at-recruitseq-4322007892?_l=en
# {'name': 'RecruitSeq', 'website_url': 'https://www.linkedin.com/company/recruitseq?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGI4JyGnK0WCg/company-logo_100_100/B4EZZZmso6HUAQ-/0/1745260039014/recruitseq_logo?e=2147483647&v=beta&t=8vvjpJhEEb5V6KlZrwvdX8AWhMPenh67z8f2I-1N0Jg'}
# ✅ Successfully inserted: Artificial Intelligence Engineer
# Cohesity https://www.linkedin.com/jobs/view/ai-software-engineer-new-graduate-at-cohesity-4336125468?_l=en
# {'name': 'Cohesity', 'website_url': 'https://www.linkedin.com/company/cohesity?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFXZ2Hda_puGA/company-logo_100_100/B56ZXZqwVUHEAY-/0/1743113619242/cohesity_logo?e=2147483647&v=beta&t=Xm_ovt5DUQMGQETaHBrDcDmRzdMmFnvbVuEvG-Le9Bo'}
# ✅ Successfully inserted: AI Software Engineer- New Graduate
# SLB https://www.linkedin.com/jobs/view/data-scientist-at-slb-4322605554?_l=en
# {'name': 'SLB', 'website_url': 'https://www.linkedin.com/company/slbglobal?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFwhnoORL25KA/company-logo_100_100/company-logo_100_100/0/1666604496648/slbdigital_logo?e=2147483647&v=beta&t=Dx2L1wl4X53IDx6PaM6zRv90UelSa7pTdmJ32guEWpA'}
# ✅ Successfully inserted: Data Scientist
# Catalyst Labs https://www.linkedin.com/jobs/view/ml-engineer-at-catalyst-labs-4322560584?_l=en
# {'name': 'Catalyst Labs', 'website_url': 'https://www.linkedin.com/company/catalystlabssl?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQEcF6HUlv4_nw/company-logo_100_100/company-logo_100_100/0/1710726945004/catalystlabssl_logo?e=2147483647&v=beta&t=QW4EEq6JmkM9VMjOTAVo01G0fYtmuAOXFkAjAX3jP7o'}
# ✅ Successfully inserted: ML Engineer
# Google https://www.linkedin.com/jobs/view/data-scientist-ads-insight-and-measurement-at-google-4321945070?_l=en
# {'name': 'Google', 'website_url': 'https://www.linkedin.com/company/google?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGv3cqOuUMY7g/company-logo_100_100/B4EZmhegXHGcAU-/0/1759350753990/google_logo?e=2147483647&v=beta&t=zYekdwB_mnXarr4wa4kw8w3Jikm8YaakM5aiDyAyvP0'}
# ✅ Successfully inserted: Data scientist, Ads Insight and Measurement
# Pathway https://www.linkedin.com/jobs/view/machine-learning-researcher-engineer-foundational-models-at-pathway-4336110010?_l=en
# {'name': 'Pathway', 'website_url': 'https://www.linkedin.com/company/pathway?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQHC6Cx7vYk2Lg/company-logo_100_100/B4EZgcqfLmHIAQ-/0/1752827557161/pathway_logo?e=2147483647&v=beta&t=iG2wM1erAOl9B5nrvFMPY-4oVohAonFS73bDgM7S54w'}
# ✅ Successfully inserted: Machine Learning Researcher / Engineer (Foundational Models)
# TikTok https://www.linkedin.com/jobs/view/machine-learning-engineer-graduate-commerce-content-service-search-ads-general-hire-2025-start-bs-ms-at-tiktok-4166793774?_l=en
# {'name': 'TikTok', 'website_url': 'https://www.linkedin.com/company/tiktok?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQHYzDOZhwEZ7Q/company-logo_100_100/B56Zl_CaXSIAAU-/0/1758772964879/tiktok_logo?e=2147483647&v=beta&t=pOXL9bnyBOPMlI34LzNiPIxaX9lk7ry0r40olePnSGE'}
# ✅ Successfully inserted: Machine Learning Engineer Graduate (Commerce& Content Service & Search Ads)-(General Hire) 2025 Start(BS/MS)
# Zoom https://www.linkedin.com/jobs/view/ai-engineer-agent-automation-at-zoom-4315633883?_l=en
# {'name': 'Zoom', 'website_url': 'https://www.linkedin.com/company/zoom?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQHdFe3fnAvRmg/company-logo_100_100/company-logo_100_100/0/1711361750580/zoom_video_communications_logo?e=2147483647&v=beta&t=WnLR8W2ykwcACgnjPlTOSUFD_7uwgSPUrQvCpEK1IP0'}
# ✅ Successfully inserted: AI Engineer - Agent Automation
# Google https://www.linkedin.com/jobs/view/staff-software-engineer-ai-ml-geo-perception-team-at-google-4321757346?_l=en
# {'name': 'Google', 'website_url': 'https://www.linkedin.com/company/google?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGv3cqOuUMY7g/company-logo_100_100/B4EZmhegXHGcAU-/0/1759350753990/google_logo?e=2147483647&v=beta&t=zYekdwB_mnXarr4wa4kw8w3Jikm8YaakM5aiDyAyvP0'}
# ✅ Successfully inserted: Staff Software Engineer, AI/ML, Geo Perception Team
# TikTok https://www.linkedin.com/jobs/view/engineer-graduate-machine-learning-engineer-graduate-data-search-tiktok-2026-start-bs-ms-at-tiktok-4281123069?_l=en
# {'name': 'TikTok', 'website_url': 'https://www.linkedin.com/company/tiktok?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQHYzDOZhwEZ7Q/company-logo_100_100/B56Zl_CaXSIAAU-/0/1758772964879/tiktok_logo?e=2147483647&v=beta&t=pOXL9bnyBOPMlI34LzNiPIxaX9lk7ry0r40olePnSGE'}
# ✅ Successfully inserted: Engineer Graduate: (Machine Learning Engineer Graduate-Data-Search-TikTok) - 2026 Start (BS/MS)
# Nuro https://www.linkedin.com/jobs/view/software-engineer-machine-learning-3d-reconstruction-at-nuro-4203026001?_l=en
# {'name': 'Nuro', 'website_url': 'https://www.linkedin.com/company/nuro-inc.?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQHahNycmNp6Gg/company-logo_100_100/company-logo_100_100/0/1630638403898/nuro_inc_logo?e=2147483647&v=beta&t=3FVrqvduIGtnaH7-fVEnLalZbqxzzCLA1ALuQ76cgmc'}
# ✅ Successfully inserted: Software Engineer, Machine Learning, 3D Reconstruction
# Agilesoft https://www.linkedin.com/jobs/view/research-engineer-applied-ai-at-agilesoft-4336155367?_l=en
# {'name': 'Agilesoft', 'website_url': 'https://it.linkedin.com/company/agilesoft-it?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4D0BAQF8B-OH23vbuw/company-logo_100_100/company-logo_100_100/0/1711100035067/agilesoft_srl_logo?e=2147483647&v=beta&t=J8UyG94s5RW_NpCvVFyjmkp4N4M0_vJehzyZO81Kz50'}
# ✅ Successfully inserted: Research Engineer - Applied AI
# Noblesoft Technologies https://www.linkedin.com/jobs/view/senior-ai-developer-at-noblesoft-technologies-4335505196?_l=en
# {'name': 'Noblesoft Technologies', 'website_url': 'https://www.linkedin.com/company/noblesoftusa?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQE0KwuTNrR_Tw/company-logo_100_100/company-logo_100_100/0/1659502900749/noblesoftusa_logo?e=2147483647&v=beta&t=iJRcrC_jvGlEWWkr1UDDkkbvDvnAnt7yRDS-MnHYhD4'}
# ✅ Successfully inserted: Senior AI Developer
# Snowflake https://www.linkedin.com/jobs/view/ai-ml-frontend-engineer-at-snowflake-4296903563?_l=en
# {'name': 'Snowflake', 'website_url': 'https://www.linkedin.com/company/snowflake-computing?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQF3mYS3WqCB3g/company-logo_100_100/company-logo_100_100/0/1688575708630/snowflake_computing_logo?e=2147483647&v=beta&t=R_pYaCE7YEAGMVV51a5YGr9L60KM56sxCoIGCUqAlmg'}
# ✅ Successfully inserted: AI/ML Frontend Engineer
# Catalyst Labs https://www.linkedin.com/jobs/view/ml-engineer-at-catalyst-labs-4322650465?_l=en
# {'name': 'Catalyst Labs', 'website_url': 'https://www.linkedin.com/company/catalystlabssl?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQEcF6HUlv4_nw/company-logo_100_100/company-logo_100_100/0/1710726945004/catalystlabssl_logo?e=2147483647&v=beta&t=QW4EEq6JmkM9VMjOTAVo01G0fYtmuAOXFkAjAX3jP7o'}
# ✅ Successfully inserted: ML Engineer
# Catalyst Labs https://www.linkedin.com/jobs/view/ml-engineer-at-catalyst-labs-4322650462?_l=en
# {'name': 'Catalyst Labs', 'website_url': 'https://www.linkedin.com/company/catalystlabssl?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQEcF6HUlv4_nw/company-logo_100_100/company-logo_100_100/0/1710726945004/catalystlabssl_logo?e=2147483647&v=beta&t=QW4EEq6JmkM9VMjOTAVo01G0fYtmuAOXFkAjAX3jP7o'}
# ✅ Successfully inserted: ML Engineer
# Typeface https://www.linkedin.com/jobs/view/ml-engineer-at-typeface-4303840454?_l=en
# {'name': 'Typeface', 'website_url': 'https://www.linkedin.com/company/typefaceai?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C4E0BAQF1toNGwK14PA/company-logo_100_100/company-logo_100_100/0/1677601239983/typefaceai_logo?e=2147483647&v=beta&t=4mU0ro-Of_OBBlD_ql_itNJl1j9ejzK1C2CxGRTEcLQ'}
# ✅ Successfully inserted: ML Engineer
# Adobe https://www.linkedin.com/jobs/view/machine-learning-engineer-2-at-adobe-4272847842?_l=en
# {'name': 'Adobe', 'website_url': 'https://www.linkedin.com/company/adobe?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQGC2hUlr9Q3ew/company-logo_100_100/B56ZodIZwJIYAQ-/0/1761425334437?e=2147483647&v=beta&t=dlK0eaMd_N-qN_Ep_PJOF-lz5NPSoolYQhlrWlwkAXY'}
# ✅ Successfully inserted: Machine Learning Engineer 2
# MLabs https://www.linkedin.com/jobs/view/ai-engineer-at-mlabs-4336141196?_l=en
# {'name': 'MLabs', 'website_url': 'https://uk.linkedin.com/company/mlabsconsulting?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGv8uRP_dCrEA/company-logo_100_100/company-logo_100_100/0/1665415880554/mlabsconsulting_logo?e=2147483647&v=beta&t=b47Kvt6bv7PLKt27WLg2Hfzc3K8wTSPbR-Im4CdS7i0'}
# ✅ Successfully inserted: AI Engineer
# Alation https://www.linkedin.com/jobs/view/ai-ml-engineer-at-alation-4322490860?_l=en
# {'name': 'Alation', 'website_url': 'https://www.linkedin.com/company/alation?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQHAeTuyeaeFUQ/company-logo_100_100/company-logo_100_100/0/1726324067602/alation_logo?e=2147483647&v=beta&t=9vIseiTzDw0zH6f7D1pZ0c0vkF4_5pnXIHiW-9o-pJk'}
# ✅ Successfully inserted: AI/ML Engineer
# Zoox https://www.linkedin.com/jobs/view/machine-learning-engineer-mapping-at-zoox-4204297989?_l=en
# {'name': 'Zoox', 'website_url': 'https://www.linkedin.com/company/zoox-inc?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQF2yqp_9BrVew/company-logo_100_100/company-logo_100_100/0/1654722579134/zoox_inc_logo?e=2147483647&v=beta&t=FPOUudBcBpcmNhUMYHw7uRlMo-NKIB7qyShJckxj1LA'}
# ✅ Successfully inserted: Machine Learning Engineer - Mapping
# Enigma https://www.linkedin.com/jobs/view/machine-learning-engineer-python-pytorch-distributed-training-optimisation-gpu-hybrid-san-jose-ca-at-enigma-4322100604?_l=en
# {'name': 'Enigma', 'website_url': 'https://uk.linkedin.com/company/enigma-rec?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQFEqpNFpIoqsQ/company-logo_100_100/company-logo_100_100/0/1713259859209/enigma_rec_logo?e=2147483647&v=beta&t=VibBiUNUOjp9qLb0JtkvwS1SDXMUDq_aeMkuK_OjT78'}
# ✅ Successfully inserted: Machine Learning Engineer | Python | Pytorch | Distributed Training | Optimisation | GPU | Hybrid, San Jose, CA
# Evolve Group https://www.linkedin.com/jobs/view/machine-learning-engineer-at-evolve-group-4340215018?_l=en
# {'name': 'Evolve Group', 'website_url': 'https://uk.linkedin.com/company/evolvegrp?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C4E0BAQFWoXpgJSRA8Q/company-logo_100_100/company-logo_100_100/0/1653925776936/evolveai_logo?e=2147483647&v=beta&t=Q5TXzhrNimomDhWpSL8nW6CRxPeUYXYgOp2NVgILJmY'}
# ✅ Successfully inserted: Machine Learning Engineer
# TikTok https://www.linkedin.com/jobs/view/machine-learning-engineer-graduate-tiktok-e-commerce-conversational-ai-2025-start-ms-at-tiktok-4076512025?_l=en
# {'name': 'TikTok', 'website_url': 'https://www.linkedin.com/company/tiktok?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQHYzDOZhwEZ7Q/company-logo_100_100/B56Zl_CaXSIAAU-/0/1758772964879/tiktok_logo?e=2147483647&v=beta&t=pOXL9bnyBOPMlI34LzNiPIxaX9lk7ry0r40olePnSGE'}
# ✅ Successfully inserted: Machine Learning Engineer Graduate (TikTok E-Commerce - Conversational AI)-2025 Start (MS)
# Experis https://www.linkedin.com/jobs/view/ai-machine-learning-engineer-%E2%80%93-agentic-ai-llm-systems-at-experis-4321835230?_l=en
# {'name': 'Experis', 'website_url': 'https://www.linkedin.com/company/experis?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFymtQZ8APcNA/company-logo_100_100/company-logo_100_100/0/1719857601343/experis_logo?e=2147483647&v=beta&t=lvDPegdIfvmMjtAHNTHMLXjuzX3e5d1nGmGoPEiBQ3w'}
# ✅ Successfully inserted: AI / Machine Learning Engineer – Agentic AI & LLM Systems
# Uber https://www.linkedin.com/jobs/view/machine-learning-engineer-ii-at-uber-4335947678?_l=en
# {'name': 'Uber', 'website_url': 'https://www.linkedin.com/company/uber-com?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C4D0BAQFiYnR1Mbtxdg/company-logo_100_100/company-logo_100_100/0/1630552741617/uber_com_logo?e=2147483647&v=beta&t=eLjukYsixVQJyGQQ7asxFiNOUNa3RVdnAMESgTWs_AQ'}
# ✅ Successfully inserted: Machine Learning Engineer II
# Zoox https://www.linkedin.com/jobs/view/machine-learning-engineer-generative-ai-at-zoox-4278980123?_l=en
# {'name': 'Zoox', 'website_url': 'https://www.linkedin.com/company/zoox-inc?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQF2yqp_9BrVew/company-logo_100_100/company-logo_100_100/0/1654722579134/zoox_inc_logo?e=2147483647&v=beta&t=FPOUudBcBpcmNhUMYHw7uRlMo-NKIB7qyShJckxj1LA'}
# ✅ Successfully inserted: Machine Learning Engineer - Generative AI
# Muro AI https://www.linkedin.com/jobs/view/founding-engineer-ai-at-muro-ai-4335325796?_l=en
# {'name': 'Muro AI', 'website_url': 'https://www.linkedin.com/company/muroai?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGftQHFc42d_g/company-logo_100_100/B4EZYYeyJbGYAQ-/0/1744167445378/muroai_logo?e=2147483647&v=beta&t=Cc87GCXCzrzSeC5owONkoD2AfJhLV5Uh_HmkiO3XlnI'}
# ✅ Successfully inserted: Founding Engineer - AI
# Stanford Health Care https://www.linkedin.com/jobs/view/data-engineer-ai-ml-at-stanford-health-care-4336106365?_l=en
# {'name': 'Stanford Health Care', 'website_url': 'https://www.linkedin.com/company/stanford-health-care?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQEBIDb6mGGGIg/company-logo_100_100/B56ZVn5GzVGQAU-/0/1741204779186/stanford_health_care_logo?e=2147483647&v=beta&t=TYf7i0s7rVryiK2MT1VDTvb2y7_s_ETNPe4HMfXOELY'}
# ✅ Successfully inserted: Data Engineer - AI/ML
# Google https://www.linkedin.com/jobs/view/senior-software-engineer-ai-ml-search-at-google-4321467949?_l=en
# {'name': 'Google', 'website_url': 'https://www.linkedin.com/company/google?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGv3cqOuUMY7g/company-logo_100_100/B4EZmhegXHGcAU-/0/1759350753990/google_logo?e=2147483647&v=beta&t=zYekdwB_mnXarr4wa4kw8w3Jikm8YaakM5aiDyAyvP0'}
# ✅ Successfully inserted: Senior Software Engineer, AI/ML, Search
# LinkedIn https://www.linkedin.com/jobs/view/senior-ai-engineer-at-linkedin-4336024944?_l=en
# {'name': 'LinkedIn', 'website_url': 'https://www.linkedin.com/company/linkedin?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQHaVYd13rRz3A/company-logo_100_100/company-logo_100_100/0/1638831590218/linkedin_logo?e=2147483647&v=beta&t=_PvUQac1LcQjfzQ33gtxFqjvIxBbtsM9ZqIxLs5QcFI'}
# ✅ Successfully inserted: Senior AI Engineer
# Goliath Partners https://www.linkedin.com/jobs/view/artificial-intelligence-engineer-at-goliath-partners-4336221059?_l=en
# {'name': 'Goliath Partners', 'website_url': 'https://www.linkedin.com/company/goliath-partners-inc?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C4E0BAQEGxoU_V_HCSw/company-logo_100_100/company-logo_100_100/0/1675096738538/goliath_partners_inc_logo?e=2147483647&v=beta&t=pEYU0RTmB4g46ZFJPdP_9yJJrE2szrWSQ250SHy4RrU'}
# ✅ Successfully inserted: Artificial Intelligence Engineer
# Databricks https://www.linkedin.com/jobs/view/data-scientist-new-grad-2026-start-at-databricks-4297746037?_l=en
# {'name': 'Databricks', 'website_url': 'https://www.linkedin.com/company/databricks?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFPIRKiPVETuw/company-logo_100_100/company-logo_100_100/0/1697215766274?e=2147483647&v=beta&t=K5mi1ouCxRu2wpiCv1XfYxu29YGccouH7wYiGiXNNpQ'}
# ✅ Successfully inserted: Data Scientist - New Grad (2026 Start)
# Cisco https://www.linkedin.com/jobs/view/ai-machine-learning-engineer-ii-intern-united-states-at-cisco-4336142624?_l=en
# {'name': 'Cisco', 'website_url': 'https://www.linkedin.com/company/cisco?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFYnR_Zrm87Dg/company-logo_100_100/B56ZnMyVr4HUAQ-/0/1760077372453/cisco_logo?e=2147483647&v=beta&t=-FnJBwOSzJBs2mZI3Vt8hsrLNZhBuwEXpMas5hClACE'}
# ✅ Successfully inserted: AI Machine Learning Engineer II (Intern) - United States
# Catalyst Labs https://www.linkedin.com/jobs/view/ml-engineer-at-catalyst-labs-4322720433?_l=en
# {'name': 'Catalyst Labs', 'website_url': 'https://www.linkedin.com/company/catalystlabssl?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQEcF6HUlv4_nw/company-logo_100_100/company-logo_100_100/0/1710726945004/catalystlabssl_logo?e=2147483647&v=beta&t=QW4EEq6JmkM9VMjOTAVo01G0fYtmuAOXFkAjAX3jP7o'}
# ✅ Successfully inserted: ML Engineer
# TikTok https://www.linkedin.com/jobs/view/machine-learning-engineer-graduate-e-commerce-recommendation-search-alliance-2025-start-ms-at-tiktok-4076507082?_l=en
# {'name': 'TikTok', 'website_url': 'https://www.linkedin.com/company/tiktok?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQHYzDOZhwEZ7Q/company-logo_100_100/B56Zl_CaXSIAAU-/0/1758772964879/tiktok_logo?e=2147483647&v=beta&t=pOXL9bnyBOPMlI34LzNiPIxaX9lk7ry0r40olePnSGE'}
# ✅ Successfully inserted: Machine Learning Engineer Graduate (E-Commerce Recommendation/Search Alliance)- 2025 Start (MS)
# Snap Inc. https://www.linkedin.com/jobs/view/machine-learning-engineer-level-4-at-snap-inc-4308939505?_l=en
# {'name': 'Snap Inc.', 'website_url': 'https://www.linkedin.com/company/snap-inc-co?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGS67pnekd_qQ/company-logo_100_100/company-logo_100_100/0/1706902360485/snap_inc_co_logo?e=2147483647&v=beta&t=WqXTKQ_yc3GViK-wcqFcRROevEPpx7q2482SqaDRSh0'}
# ✅ Successfully inserted: Machine Learning Engineer, Level 4
# LinkedIn https://www.linkedin.com/jobs/view/software-engineer-ai-platform-at-linkedin-4317358470?_l=en
# {'name': 'LinkedIn', 'website_url': 'https://www.linkedin.com/company/linkedin?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQHaVYd13rRz3A/company-logo_100_100/company-logo_100_100/0/1638831590218/linkedin_logo?e=2147483647&v=beta&t=_PvUQac1LcQjfzQ33gtxFqjvIxBbtsM9ZqIxLs5QcFI'}
# ✅ Successfully inserted: Software Engineer, AI Platform
# Google https://www.linkedin.com/jobs/view/software-engineer-ai-ml-youtube-ads-creative-optimization-at-google-4321805263?_l=en
# {'name': 'Google', 'website_url': 'https://www.linkedin.com/company/google?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGv3cqOuUMY7g/company-logo_100_100/B4EZmhegXHGcAU-/0/1759350753990/google_logo?e=2147483647&v=beta&t=zYekdwB_mnXarr4wa4kw8w3Jikm8YaakM5aiDyAyvP0'}
# ✅ Successfully inserted: Software Engineer, AI/ML, YouTube Ads Creative Optimization
# DeepScribe https://www.linkedin.com/jobs/view/ai-engineer-at-deepscribe-4339974796?_l=en
# {'name': 'DeepScribe', 'website_url': 'https://www.linkedin.com/company/deepscribe?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFEqRtxJI_8ow/company-logo_100_100/B56ZiapZbfHkAQ-/0/1754941200722/deepscribe_logo?e=2147483647&v=beta&t=MMyTpsozzJvpxocCy8BXlXElB2X_siVKrEscUgc48rE'}
# ✅ Successfully inserted: AI Engineer
# Oracle https://www.linkedin.com/jobs/view/principal-software-development-engineer-at-oracle-4286759911?_l=en
# {'name': 'Oracle', 'website_url': 'https://www.linkedin.com/company/oracle?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQHYCgYovUuPtQ/company-logo_100_100/company-logo_100_100/0/1665755678957/oracle_logo?e=2147483647&v=beta&t=55lZDJhHdt3oPj2_gdPpymKz6Wv_9atXeO-CBFzAm6c'}
# ✅ Successfully inserted: Principal Software Development Engineer
# Adobe https://www.linkedin.com/jobs/view/machine-learning-engineer-at-adobe-4316653556?_l=en
# {'name': 'Adobe', 'website_url': 'https://www.linkedin.com/company/adobe?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQGC2hUlr9Q3ew/company-logo_100_100/B56ZodIZwJIYAQ-/0/1761425334437?e=2147483647&v=beta&t=dlK0eaMd_N-qN_Ep_PJOF-lz5NPSoolYQhlrWlwkAXY'}
# ✅ Successfully inserted: Machine Learning Engineer
# PwC https://www.linkedin.com/jobs/view/pwc-technology-senior-ai-engineer-at-pwc-4317434985?_l=en
# {'name': 'PwC', 'website_url': 'https://uk.linkedin.com/company/pwc?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQFVfAbYbmcpvA/company-logo_100_100/B4EZaB6j58H0AQ-/0/1745936334912/pwc_logo?e=2147483647&v=beta&t=stNIhYwMNfiRmzhcYIuKvLl6j-_E5sJ8JNb3x27Tv1s'}
# ✅ Successfully inserted: PwC Technology - Senior AI Engineer
# Sonatus https://www.linkedin.com/jobs/view/staff-cloud-backend-engineer-at-sonatus-4306645520?_l=en
# {'name': 'Sonatus', 'website_url': 'https://www.linkedin.com/company/sonatus?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQHEe_GcWmxbAQ/company-logo_100_100/company-logo_100_100/0/1685915668604/sonatus_logo?e=2147483647&v=beta&t=rQCyGMjMxWVcMP4XooyJav6qONJVQ9UuHiVuvQVWczY'}
# ✅ Successfully inserted: Staff Cloud Backend Engineer
# Groq https://www.linkedin.com/jobs/view/staff-infrastructure-engineer-at-groq-4318177255?_l=en
# {'name': 'Groq', 'website_url': 'https://www.linkedin.com/company/groq?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQHu2B6mxi4DzA/company-logo_100_100/B56ZmD6jUWI0AQ-/0/1758854788647/groq_logo?e=2147483647&v=beta&t=LdTc8iHSbuSdP0_1fqeO8EUpNLTqb_DYOIb7gdMAIOY'}
# ✅ Successfully inserted: Staff Infrastructure Engineer
# Rivian and Volkswagen Group Technologies https://www.linkedin.com/jobs/view/sr-systems-engineer-body-controls-vehicle-access-at-rivian-and-volkswagen-group-technologies-4298321150?_l=en
# {'name': 'Rivian and Volkswagen Group Technologies', 'website_url': 'https://www.linkedin.com/company/rivian-and-vw-group-technologies?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFgt-xXXDMIuA/company-logo_100_100/B56Zld4a7yG4AQ-/0/1758216695870/rivian_and_vw_group_technologies_logo?e=2147483647&v=beta&t=QKt7_2_85SZzDzp91wt16EOSFomsJR-L2VKr7RQZWsQ'}
# ✅ Successfully inserted: Sr. Systems Engineer, Body Controls (Vehicle Access)
# Capital One https://www.linkedin.com/jobs/view/lead-ai-engineer-ai-foundations-llm-core-at-capital-one-4298200495?_l=en
# {'name': 'Capital One', 'website_url': 'https://www.linkedin.com/company/capital-one?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQF0OgQyRZ9yAA/company-logo_100_100/company-logo_100_100/0/1635782718446/capital_one_logo?e=2147483647&v=beta&t=3vOvEagCN6Oz8iNwzA1s1AyoVUy5mbl-0M0gQjeiKvs'}
# ✅ Successfully inserted: Lead AI Engineer (AI Foundations, LLM Core)
# Weights & Biases https://www.linkedin.com/jobs/view/production-engineer-at-weights-biases-4340631543?_l=en
# {'name': 'Weights & Biases', 'website_url': 'https://www.linkedin.com/company/wandb?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQE1psrG0-eZ3g/company-logo_100_100/company-logo_100_100/0/1730486431113/wandb_logo?e=2147483647&v=beta&t=_VbiSzgTBDn2T_Rh0FWVLj8YIlxVJBZx8e3LIF3mNuw'}
# ✅ Successfully inserted: Production Engineer
# Atlassian https://www.linkedin.com/jobs/view/machine-learning-engineer-at-atlassian-4308683431?_l=en
# {'name': 'Atlassian', 'website_url': 'https://au.linkedin.com/company/atlassian?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGeyLL6crkJKg/company-logo_100_100/company-logo_100_100/0/1735593604612/atlassian_logo?e=2147483647&v=beta&t=4riZdTtd16Oeoew0_mSThLQak3uyYv2-ep73cztBjbo'}
# ✅ Successfully inserted: Machine Learning Engineer
# AMD https://www.linkedin.com/jobs/view/feature-validation-test-engineer-cloud-at-amd-4286749807?_l=en
# {'name': 'AMD', 'website_url': 'https://www.linkedin.com/company/amd?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFCdxxVA_xhqQ/company-logo_100_100/B56ZnuIjafHUAU-/0/1760636844195/amd_logo?e=2147483647&v=beta&t=7sw3BjNNNSGV0P6imSg3j1KA9Z07vLBQjTYIMB-k8zI'}
# ✅ Successfully inserted: Feature Validation/Test Engineer-Cloud
# Waymo https://www.linkedin.com/jobs/view/ml-deep-learning-engineer-at-waymo-4315240585?_l=en
# {'name': 'Waymo', 'website_url': 'https://www.linkedin.com/company/waymo?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C4E0BAQG4FdRM0dx-3w/company-logo_100_100/company-logo_100_100/0/1631313981466?e=2147483647&v=beta&t=IXtObZfNgdF5FyE--mcDrY2MfqC_c4AwN-XzHeJGAj4'}
# ✅ Successfully inserted: ML / Deep Learning Engineer
# Cisco https://www.linkedin.com/jobs/view/ai-machine-learning-engineer-i-intern-united-states-at-cisco-4335954312?_l=en
# {'name': 'Cisco', 'website_url': 'https://www.linkedin.com/company/cisco?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFYnR_Zrm87Dg/company-logo_100_100/B56ZnMyVr4HUAQ-/0/1760077372453/cisco_logo?e=2147483647&v=beta&t=-FnJBwOSzJBs2mZI3Vt8hsrLNZhBuwEXpMas5hClACE'}
# ✅ Successfully inserted: AI Machine Learning Engineer I (Intern) - United States
# Nuro https://www.linkedin.com/jobs/view/software-engineer-map-ml-platform-at-nuro-4102824034?_l=en
# {'name': 'Nuro', 'website_url': 'https://www.linkedin.com/company/nuro-inc.?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQHahNycmNp6Gg/company-logo_100_100/company-logo_100_100/0/1630638403898/nuro_inc_logo?e=2147483647&v=beta&t=3FVrqvduIGtnaH7-fVEnLalZbqxzzCLA1ALuQ76cgmc'}
# ✅ Successfully inserted: Software Engineer, Map ML Platform
# Intuit https://www.linkedin.com/jobs/view/machine-learning-engineer-2-at-intuit-4331337496?_l=en
# {'name': 'Intuit', 'website_url': 'https://www.linkedin.com/company/intuit?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQFTpF8uneqScw/company-logo_100_100/company-logo_100_100/0/1661446146222/intuit_logo?e=2147483647&v=beta&t=5hsEsGdMVVpQSXz7yjJc2fshydqwaa7AOmiIPwuwgmA'}
# ✅ Successfully inserted: Machine Learning Engineer 2
# TikTok https://www.linkedin.com/jobs/view/general-hire-machine-learning-engineer-tiktok-recommendation-2025-start-master-at-tiktok-4119372113?_l=en
# {'name': 'TikTok', 'website_url': 'https://www.linkedin.com/company/tiktok?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQHYzDOZhwEZ7Q/company-logo_100_100/B56Zl_CaXSIAAU-/0/1758772964879/tiktok_logo?e=2147483647&v=beta&t=pOXL9bnyBOPMlI34LzNiPIxaX9lk7ry0r40olePnSGE'}
# ✅ Successfully inserted: (General Hire)Machine Learning Engineer (TikTok Recommendation) - 2025 Start (Master)
# Adobe https://www.linkedin.com/jobs/view/machine-learning-engineer-at-adobe-4308510108?_l=en
# {'name': 'Adobe', 'website_url': 'https://www.linkedin.com/company/adobe?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQGC2hUlr9Q3ew/company-logo_100_100/B56ZodIZwJIYAQ-/0/1761425334437?e=2147483647&v=beta&t=dlK0eaMd_N-qN_Ep_PJOF-lz5NPSoolYQhlrWlwkAXY'}
# ✅ Successfully inserted: Machine Learning Engineer
# Smart IT Frame LLC https://www.linkedin.com/jobs/view/ai-ml-engineer-at-smart-it-frame-llc-4321857491?_l=en
# {'name': 'Smart IT Frame LLC', 'website_url': 'https://www.linkedin.com/company/smart-it-frame-llc?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFp8DyHJCmFyg/company-logo_100_100/company-logo_100_100/0/1736758063216/smart_it_frame_llc_logo?e=2147483647&v=beta&t=-MDPEXzGnkSK0gzS9dkqXr4lsbV2fSf-GyL4ZFk8JjM'}
# ✅ Successfully inserted: AI ML Engineer
# Nuro https://www.linkedin.com/jobs/view/software-engineer-ai-platform-new-grad-at-nuro-4317707969?_l=en
# {'name': 'Nuro', 'website_url': 'https://www.linkedin.com/company/nuro-inc.?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQHahNycmNp6Gg/company-logo_100_100/company-logo_100_100/0/1630638403898/nuro_inc_logo?e=2147483647&v=beta&t=3FVrqvduIGtnaH7-fVEnLalZbqxzzCLA1ALuQ76cgmc'}
# ✅ Successfully inserted: Software Engineer, AI Platform - New Grad
# Autonomous Healthcare https://www.linkedin.com/jobs/view/machine-learning-engineer-data-science-at-autonomous-healthcare-4322460898?_l=en
# {'name': 'Autonomous Healthcare', 'website_url': 'https://www.linkedin.com/company/autonomous-healthcare?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C510BAQHMRkEjTefBOg/company-logo_100_100/company-logo_100_100/0/1631369035375?e=2147483647&v=beta&t=rfprePUS-CVU1xzVKbJuRZ13_aCPW2NkHUpIWVJQM5w'}
# ✅ Successfully inserted: Machine Learning Engineer (Data Science)
# Adobe https://www.linkedin.com/jobs/view/data-scientist-at-adobe-4318612659?_l=en
# {'name': 'Adobe', 'website_url': 'https://www.linkedin.com/company/adobe?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQGC2hUlr9Q3ew/company-logo_100_100/B56ZodIZwJIYAQ-/0/1761425334437?e=2147483647&v=beta&t=dlK0eaMd_N-qN_Ep_PJOF-lz5NPSoolYQhlrWlwkAXY'}
# ✅ Successfully inserted: Data Scientist
# Skild AI https://www.linkedin.com/jobs/view/machine-learning-engineer-at-skild-ai-4299098257?_l=en
# {'name': 'Skild AI', 'website_url': 'https://www.linkedin.com/company/skildai?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQHWFkaL3MJqRQ/company-logo_100_100/company-logo_100_100/0/1720503134494/skild_ai_logo?e=2147483647&v=beta&t=r-71AM518n5DHPWeeELUr5gDaiXWHvTlgTZ3ObgokRs'}
# ✅ Successfully inserted: Machine Learning Engineer
# Cisco https://www.linkedin.com/jobs/view/machine-learning-engineer-hybrid-at-cisco-4336184983?_l=en
# {'name': 'Cisco', 'website_url': 'https://www.linkedin.com/company/cisco?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFYnR_Zrm87Dg/company-logo_100_100/B56ZnMyVr4HUAQ-/0/1760077372453/cisco_logo?e=2147483647&v=beta&t=-FnJBwOSzJBs2mZI3Vt8hsrLNZhBuwEXpMas5hClACE'}
# ✅ Successfully inserted: Machine Learning Engineer (Hybrid)
# Google https://www.linkedin.com/jobs/view/staff-software-engineer-ai-ml-recommendations-rankings-predictions-google-ads-at-google-4233283966?_l=en
# {'name': 'Google', 'website_url': 'https://www.linkedin.com/company/google?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGv3cqOuUMY7g/company-logo_100_100/B4EZmhegXHGcAU-/0/1759350753990/google_logo?e=2147483647&v=beta&t=zYekdwB_mnXarr4wa4kw8w3Jikm8YaakM5aiDyAyvP0'}
# ✅ Successfully inserted: Staff Software Engineer, AI/ML Recommendations, Rankings, Predictions, Google Ads
# BILL https://www.linkedin.com/jobs/view/staff-engineer-data-platform-at-bill-4306314589?_l=en
# {'name': 'BILL', 'website_url': 'https://www.linkedin.com/company/bill?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQGaHtnxLcwWfw/company-logo_100_100/company-logo_100_100/0/1738871433540/bill_logo?e=2147483647&v=beta&t=BKZX_Cc44VELBh75-4optgvmfQnFlfuAfG0uVrdBR9M'}
# ✅ Successfully inserted: Staff Engineer, Data Platform
# Roblox https://www.linkedin.com/jobs/view/senior-principal-machine-learning-engineer-voice-safety-at-roblox-4308861650?_l=en
# {'name': 'Roblox', 'website_url': 'https://www.linkedin.com/company/roblox?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQG364JsrSwWDw/company-logo_100_100/B56ZXO1eZRGcAQ-/0/1742931879751/roblox_logo?e=2147483647&v=beta&t=QLnO1eAWpTSAtiLM39Tc6a20NU87gbiSu5y9p6y6WN0'}
# ✅ Successfully inserted: Senior/Principal Machine Learning Engineer, Voice Safety
# Gusto https://www.linkedin.com/jobs/view/principal-data-scientist-%E2%80%93-product-at-gusto-4331395330?_l=en
# {'name': 'Gusto', 'website_url': 'https://www.linkedin.com/company/gustohq?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQH658sJdurY4A/company-logo_100_100/company-logo_100_100/0/1731018699255/gustohq_logo?e=2147483647&v=beta&t=KBmRV1DXRAK4N9i9g1X0HE-NSfOShNlAkOE0CDVvHlk'}
# ✅ Successfully inserted: Principal Data Scientist – Product
# CoreWeave https://www.linkedin.com/jobs/view/production-engineer-at-coreweave-4337738188?_l=en
# {'name': 'CoreWeave', 'website_url': 'https://www.linkedin.com/company/coreweave?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4D0BAQE_ymAIwDXUAA/company-logo_100_100/company-logo_100_100/0/1738774515435/coreweave_logo?e=2147483647&v=beta&t=Vl8PMbIMaysYojTRrCvIhKQHPIggfbC3GaVS81g1bO4'}
# ✅ Successfully inserted: Production Engineer
# Cadence https://www.linkedin.com/jobs/view/ai-senior-staff-systems-engineer-at-cadence-4305856555?_l=en
# {'name': 'Cadence', 'website_url': 'https://www.linkedin.com/company/cadence?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQFORFBYBIoPHQ/company-logo_100_100/company-logo_100_100/0/1630668285973?e=2147483647&v=beta&t=2J-kabPjQZhiv-NQmJBV5GTY1H_oVFa73HtuaA2-b0M'}
# ✅ Successfully inserted: AI Senior Staff Systems Engineer
# Otter.ai https://www.linkedin.com/jobs/view/staff-software-engineer-infrastructure-ml-and-real-time-speech-at-otter-ai-4335996043?_l=en
# {'name': 'Otter.ai', 'website_url': 'https://www.linkedin.com/company/otter-ai?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFUOYiiiVRk7Q/company-logo_100_100/B56ZfG6wdAHoAY-/0/1751388981421/otter_ai_logo?e=2147483647&v=beta&t=Xb25VhjPEj5d230vWx03XIi66oiID0PAnmvuIMDu8rw'}
# ✅ Successfully inserted: Staff Software Engineer, Infrastructure (ML and Real-Time Speech)
# Machinify https://www.linkedin.com/jobs/view/staff-software-engineer-backend-remote-at-machinify-4253546006?_l=en
# {'name': 'Machinify', 'website_url': 'https://www.linkedin.com/company/machinify?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQFzwCcQrMIEHg/company-logo_100_100/B4EZnDnS5WKkAQ-/0/1759923482489/machinify_logo?e=2147483647&v=beta&t=dKpCE8fRy_4vVsU2-kR8QE40IYeefuOaK-jYmwdPw-k'}
# ✅ Successfully inserted: Staff Software Engineer, Backend (Remote)
# xAI https://www.linkedin.com/jobs/view/member-of-technical-staff-image-generation-at-xai-4262581092?_l=en
# {'name': 'xAI', 'website_url': 'https://www.linkedin.com/company/xai?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFGK5Kkd1nUlg/company-logo_100_100/company-logo_100_100/0/1738099065875/xai_logo?e=2147483647&v=beta&t=amK7u3-FiysFFYuhJkxR98gQFUjCzgudn14_jkq4twc'}
# ✅ Successfully inserted: Member of Technical Staff, Image Generation
# ExecutivePlacements.com https://www.linkedin.com/jobs/view/wireless-software-engineer-at-executiveplacements-com-4335950803?_l=en
# {'name': 'ExecutivePlacements.com', 'website_url': 'https://www.linkedin.com/company/executive-placements?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C4D0BAQHcENc73eQOPA/company-logo_100_100/company-logo_100_100/0/1632409239699/executive_placements_logo?e=2147483647&v=beta&t=DbV0Do7vchLpeWtg-zU7m3Mx3EEqZRx4A9V4xPG4tPs'}
# ✅ Successfully inserted: Wireless Software Engineer
# Fractal https://www.linkedin.com/jobs/view/decision-scientist-at-fractal-4322062398?_l=en
# {'name': 'Fractal', 'website_url': 'https://www.linkedin.com/company/fractal-analytics?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4D0BAQFfWiLKapr2dg/company-logo_100_100/company-logo_100_100/0/1739206750155/fractal_analytics_logo?e=2147483647&v=beta&t=u3TAvymPT_vd6sLm-gjz1eKA_fda94JsF73pXnSd9nU'}
# ✅ Successfully inserted: Decision Scientist
# ByteDance https://www.linkedin.com/jobs/view/software-engineer-graduate-applied-machine-learning-inference-2026-start-ms-at-bytedance-4287418360?_l=en
# {'name': 'ByteDance', 'website_url': 'https://cn.linkedin.com/company/bytedance?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQGA-1ynUGnhlA/company-logo_100_100/company-logo_100_100/0/1630658803864/bytedance_logo?e=2147483647&v=beta&t=v5Ul65QdIzJoz0_gq79gs-Y4ilhMRoNUk_Z44By-iOA'}
# ✅ Successfully inserted: Software Engineer Graduate (Applied Machine Learning - Inference) - 2026 Start (MS)
# Commure https://www.linkedin.com/jobs/view/senior-fullstack-engineer-patientkeeper-at-commure-4318285819?_l=en
# {'name': 'Commure', 'website_url': 'https://www.linkedin.com/company/commure?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQEgIrZgUJrUtQ/company-logo_100_100/company-logo_100_100/0/1650989688925/commure_logo?e=2147483647&v=beta&t=pZoc8UGynUNxdPa6AeCGqpnezI2AGlWm0wDP50M7VrA'}
# ✅ Successfully inserted: Senior Fullstack Engineer, PatientKeeper
# Zoom https://www.linkedin.com/jobs/view/video-ai-engineer-at-zoom-4204732571?_l=en
# {'name': 'Zoom', 'website_url': 'https://www.linkedin.com/company/zoom?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQHdFe3fnAvRmg/company-logo_100_100/company-logo_100_100/0/1711361750580/zoom_video_communications_logo?e=2147483647&v=beta&t=WnLR8W2ykwcACgnjPlTOSUFD_7uwgSPUrQvCpEK1IP0'}
# ✅ Successfully inserted: Video AI Engineer
# Grafton Sciences https://www.linkedin.com/jobs/view/senior-robotics-simulation-engineer-at-grafton-sciences-4336250109?_l=en
# {'name': 'Grafton Sciences', 'website_url': 'https://www.linkedin.com/company/grafton-sciences?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQFe2LpgpF3RVQ/company-logo_100_100/B4EZqCKcVkJ0AU-/0/1763120367237/grafton_sciences_logo?e=2147483647&v=beta&t=GQLNbxqTQoujcEigjVufZ4JOGushsJw8efB8zoREykI'}
# ✅ Successfully inserted: Senior Robotics Simulation Engineer
# JPMorganChase https://www.linkedin.com/jobs/view/principle-software-engineer-at-jpmorganchase-4310181874?_l=en
# {'name': 'JPMorganChase', 'website_url': 'https://www.linkedin.com/company/jpmorganchase?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGxpntCyRgsuA/company-logo_100_100/company-logo_100_100/0/1718711710850/jpmorganchase_logo?e=2147483647&v=beta&t=kP6Xf9uye25nDGkk4RmP87zYyfNqaQWny7e5o3WyKhI'}
# ✅ Successfully inserted: Principle Software Engineer
# GEICO https://www.linkedin.com/jobs/view/senior-staff-engineer-interactive-voice-response-ai-ml-at-geico-4321576722?_l=en
# {'name': 'GEICO', 'website_url': 'https://www.linkedin.com/company/geico?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGF25KGwu06pw/company-logo_100_100/company-logo_100_100/0/1728937460623/geico_logo?e=2147483647&v=beta&t=k1CcvYdPW230WUD4VRffwKd4tGPKmYocmWoWgnVJfY4'}
# ✅ Successfully inserted: Senior Staff Engineer, Interactive Voice Response - AI/ML
# Emotion Machine https://www.linkedin.com/jobs/view/founding-engineer-at-emotion-machine-4335828101?_l=en
# {'name': 'Emotion Machine', 'website_url': 'https://www.linkedin.com/company/emotion-machine?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQENngCpfeAjdA/company-logo_100_100/B56ZpK2ZO.IcAQ-/0/1762192364897/emotion_machine_logo?e=2147483647&v=beta&t=-n8QHE9oAy45EfYsTNhjYVG-FPP2kMQ28kaMv_8iplI'}
# ✅ Successfully inserted: Founding Engineer
# NVIDIA https://www.linkedin.com/jobs/view/senior-deep-learning-engineer-genomics-at-nvidia-4335401504?_l=en
# {'name': 'NVIDIA', 'website_url': 'https://www.linkedin.com/company/nvidia?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQGV36q2EowSyw/company-logo_100_100/company-logo_100_100/0/1724881581208/nvidia_logo?e=2147483647&v=beta&t=oCxt8kGhi0AfLuVDY7D_jzkUIEe-fAV5Q5eLaRxXzOE'}
# ✅ Successfully inserted: Senior Deep Learning Engineer - Genomics
# Breakthrough Talent https://www.linkedin.com/jobs/view/software-engineer-at-breakthrough-talent-4321940370?_l=en
# {'name': 'Breakthrough Talent', 'website_url': 'https://www.linkedin.com/company/breakthrough-talent-recruitment?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGZONmSdmEy_A/company-logo_100_100/company-logo_100_100/0/1734957573773?e=2147483647&v=beta&t=TPPLsx9gCkQAjC-pRJIHst-zxjxtgDflQTXx1lVQh2M'}
# ✅ Successfully inserted: Software Engineer
# Grafton Sciences https://www.linkedin.com/jobs/view/senior-ml-infra-mlops-engineer-at-grafton-sciences-4336240169?_l=en
# {'name': 'Grafton Sciences', 'website_url': 'https://www.linkedin.com/company/grafton-sciences?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQFe2LpgpF3RVQ/company-logo_100_100/B4EZqCKcVkJ0AU-/0/1763120367237/grafton_sciences_logo?e=2147483647&v=beta&t=GQLNbxqTQoujcEigjVufZ4JOGushsJw8efB8zoREykI'}
# ✅ Successfully inserted: Senior ML Infra / MLOps Engineer
# Harnham https://www.linkedin.com/jobs/view/staff-ai-ml-engineer-at-harnham-4332325111?_l=en
# {'name': 'Harnham', 'website_url': 'https://uk.linkedin.com/company/harnham?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQFDh4hZFsU8qA/company-logo_100_100/company-logo_100_100/0/1732180104917/harnham_logo?e=2147483647&v=beta&t=2K2PZUjKIx7QPtNOXOgU2XOjaiYyj1Gnd8g_8LaDJhc'}
# ✅ Successfully inserted: Staff AI/ML Engineer
# Tiger Analytics https://www.linkedin.com/jobs/view/azure-ai-lead-engineer-at-tiger-analytics-4321911450?_l=en
# {'name': 'Tiger Analytics', 'website_url': 'https://www.linkedin.com/company/tiger-analytics?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4D0BAQE2M3YNGvX6Qg/company-logo_100_100/company-logo_100_100/0/1697546701844/tiger_analytics_logo?e=2147483647&v=beta&t=h1dPjfyfmMjEbqL9ZepvAN6goKrONemg7gFsfzI7rBM'}
# ✅ Successfully inserted: Azure AI Lead Engineer
# Google https://www.linkedin.com/jobs/view/data-scientist-iii-research-at-google-4318642105?_l=en
# {'name': 'Google', 'website_url': 'https://www.linkedin.com/company/google?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGv3cqOuUMY7g/company-logo_100_100/B4EZmhegXHGcAU-/0/1759350753990/google_logo?e=2147483647&v=beta&t=zYekdwB_mnXarr4wa4kw8w3Jikm8YaakM5aiDyAyvP0'}
# ✅ Successfully inserted: Data Scientist III, Research
# Durlston Partners https://www.linkedin.com/jobs/view/software-engineer-ai-tech-san-francisco-at-durlston-partners-4340485041?_l=en
# {'name': 'Durlston Partners', 'website_url': 'https://uk.linkedin.com/company/durlston-partners?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C4D0BAQFuuhTCF5UhNw/company-logo_100_100/company-logo_100_100/0/1630461162788/durlston_partners_llp_logo?e=2147483647&v=beta&t=DQnwSrv5bgZm4yZEj55Qo3-kzbGEKWLeP5KLLcGMMss'}
# ✅ Successfully inserted: Software Engineer - AI Tech - San Francisco
# Plenful https://www.linkedin.com/jobs/view/senior-backend-engineer-ml-ops-at-plenful-4336091066?_l=en
# {'name': 'Plenful', 'website_url': 'https://www.linkedin.com/company/plenful?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQEV0z1iQBI-Xw/company-logo_100_100/B56ZX_FNNqGsAQ-/0/1743741310142/plenful_logo?e=2147483647&v=beta&t=TBUBsqkQ9K8i0sm6dETresX0T7IT8mrP-D_u_IhgqJA'}
# ✅ Successfully inserted: Senior Backend Engineer, ML Ops
# LinkedIn https://www.linkedin.com/jobs/view/senior-staff-ai-engineer-ai-privacy-expert-at-linkedin-4336002576?_l=en
# {'name': 'LinkedIn', 'website_url': 'https://www.linkedin.com/company/linkedin?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQHaVYd13rRz3A/company-logo_100_100/company-logo_100_100/0/1638831590218/linkedin_logo?e=2147483647&v=beta&t=_PvUQac1LcQjfzQ33gtxFqjvIxBbtsM9ZqIxLs5QcFI'}
# ✅ Successfully inserted: Senior Staff AI Engineer, AI Privacy Expert
# Roblox https://www.linkedin.com/jobs/view/data-scientist-people-science-at-roblox-4317148520?_l=en
# ...
# {'name': 'Astera Labs', 'website_url': 'https://www.linkedin.com/company/astera-labs?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFiYutK-QgOhQ/company-logo_100_100/company-logo_100_100/0/1681517329665/astera_labs_logo?e=2147483647&v=beta&t=6wsFeB0TxAvl7k8a6FWuqc1HJkPchpxGsN6F9d-FgF4'}
# ✅ Successfully inserted: Principal Field Applications Engineer
# AMD https://www.linkedin.com/jobs/view/lead-software-product-support-engineer-at-amd-4324751540?_l=en
# {'name': 'AMD', 'website_url': 'https://www.linkedin.com/company/amd?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFCdxxVA_xhqQ/company-logo_100_100/B56ZnuIjafHUAU-/0/1760636844195/amd_logo?e=2147483647&v=beta&t=7sw3BjNNNSGV0P6imSg3j1KA9Z07vLBQjTYIMB-k8zI'}
# ✅ Successfully inserted: Lead Software Product Support Engineer
# Insight Global https://www.linkedin.com/jobs/view/staff-robotics-engineer-at-insight-global-4320695375?_l=en
# {'name': 'Insight Global', 'website_url': 'https://www.linkedin.com/company/insight-global?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQGUNIyRZFaj0g/company-logo_100_100/company-logo_100_100/0/1657049194702/insight_global_logo?e=2147483647&v=beta&t=DgPf2KH2qEgV2aPJ2mFY1olLW0chPXs0DYd3jAp5tQ0'}
# ✅ Successfully inserted: Staff Robotics Engineer
# Jerry https://www.linkedin.com/jobs/view/software-engineer-ii-full-stack-backend-leaning-at-jerry-4340501735?_l=en
# {'name': 'Jerry', 'website_url': 'https://www.linkedin.com/company/jerryinc?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQFn2QCrOCDMwg/company-logo_100_100/company-logo_100_100/0/1630648185818/jerryinc_logo?e=2147483647&v=beta&t=av36t83Kd04m6aR-OU4KCi1lrpySrASAdTcDVKhzXsY'}
# ✅ Successfully inserted: Software Engineer II (Full-Stack, Backend-leaning)
# webAI https://www.linkedin.com/jobs/view/staff-r-d-ai-engineer-at-webai-4270318682?_l=en
# {'name': 'webAI', 'website_url': 'https://www.linkedin.com/company/webai-official?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQG5O_MIVfPlVg/company-logo_100_100/B56ZnjP7gOHIAQ-/0/1760454228497/webai_official_logo?e=2147483647&v=beta&t=usCY4sdD22lHMDIf9Q1KTISkTXjYWZmBBKCdxZgGzSs'}
# ✅ Successfully inserted: Staff R&D AI Engineer
# athenahealth https://www.linkedin.com/jobs/view/senior-software-engineer-ai-ml-%E2%80%93-epocrates-at-athenahealth-4312744861?_l=en
# {'name': 'athenahealth', 'website_url': 'https://www.linkedin.com/company/athenahealth?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C4D0BAQEks9TxjFdIag/company-logo_100_100/company-logo_100_100/0/1632748750276/athenahealth_logo?e=2147483647&v=beta&t=KdfKkEJQ6pi67bB-DQ5A0P8jhqTGzXvBfVfc3yxyXG0'}
# ✅ Successfully inserted: Senior Software Engineer, AI/ML – epocrates
# AMD https://www.linkedin.com/jobs/view/sr-systems-validation-engineer-at-amd-4340405984?_l=en
# {'name': 'AMD', 'website_url': 'https://www.linkedin.com/company/amd?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFCdxxVA_xhqQ/company-logo_100_100/B56ZnuIjafHUAU-/0/1760636844195/amd_logo?e=2147483647&v=beta&t=7sw3BjNNNSGV0P6imSg3j1KA9Z07vLBQjTYIMB-k8zI'}
# ✅ Successfully inserted: Sr. Systems Validation Engineer
# NVIDIA https://www.linkedin.com/jobs/view/senior-ai-and-ml-hpc-cluster-engineer-at-nvidia-4316840640?_l=en
# {'name': 'NVIDIA', 'website_url': 'https://www.linkedin.com/company/nvidia?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQGV36q2EowSyw/company-logo_100_100/company-logo_100_100/0/1724881581208/nvidia_logo?e=2147483647&v=beta&t=oCxt8kGhi0AfLuVDY7D_jzkUIEe-fAV5Q5eLaRxXzOE'}
# ✅ Successfully inserted: Senior AI and ML HPC Cluster Engineer
# AMD https://www.linkedin.com/jobs/view/product-development-engineer-at-amd-4261198037?_l=en
# {'name': 'AMD', 'website_url': 'https://www.linkedin.com/company/amd?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFCdxxVA_xhqQ/company-logo_100_100/B56ZnuIjafHUAU-/0/1760636844195/amd_logo?e=2147483647&v=beta&t=7sw3BjNNNSGV0P6imSg3j1KA9Z07vLBQjTYIMB-k8zI'}
# ✅ Successfully inserted: Product Development Engineer
# Meta https://www.linkedin.com/jobs/view/data-scientist-product-analytics-at-meta-4120825428?_l=en
# {'name': 'Meta', 'website_url': 'https://www.linkedin.com/company/meta?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQHBmbxCDP0JQQ/company-logo_100_100/B56ZlkdQSaI8AQ-/0/1758327015620/meta_logo?e=2147483647&v=beta&t=wKpKTUGAcanUzVRxCutYYO3NJ_Etr5c4n2AbPyOu260'}
# ✅ Successfully inserted: Data Scientist, Product Analytics
# Charles Schwab https://www.linkedin.com/jobs/view/ai-platform-security-engineer-at-charles-schwab-4313365240?_l=en
# {'name': 'Charles Schwab', 'website_url': 'https://www.linkedin.com/company/charles-schwab?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQEhQXJ0SwK6mw/company-logo_100_100/B56Zom8DevJ4AU-/0/1761589868955/charles_schwab_logo?e=2147483647&v=beta&t=hSY6R1pxAiEJJ_elGBQCfvpy8WxaoCNa71IyDze8Ww8'}
# ✅ Successfully inserted: AI Platform Security Engineer
# IBM https://www.linkedin.com/jobs/view/associate-data-scientist-intern-2026-at-ibm-4312429519?_l=en
# {'name': 'IBM', 'website_url': 'https://www.linkedin.com/company/ibm?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQGiz5ecgpCtkA/company-logo_100_100/company-logo_100_100/0/1688684715866/ibm_logo?e=2147483647&v=beta&t=HPSmWLOCvdPkWO1nRWwjjmCNpaCqww20rSJ4E54QtxQ'}
# ✅ Successfully inserted: Associate Data Scientist Intern 2026
# Arm https://www.linkedin.com/jobs/view/senior-qa-engineer-networking-for-ai-at-arm-4289487135?_l=en
# {'name': 'Arm', 'website_url': 'https://uk.linkedin.com/company/arm?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQEeZEj_YnYWeg/company-logo_100_100/B4EZXss3rjGgAU-/0/1743432940736/arm_logo?e=2147483647&v=beta&t=LQCC3V2YERRmUGVUJOG0fU8tj3srfiJ_QJsd35j4XdQ'}
# ✅ Successfully inserted: Senior QA Engineer- Networking for AI
# Deloitte https://www.linkedin.com/jobs/view/agentic-ai-ai-data-specialist-master-at-deloitte-4318200602?_l=en
# {'name': 'Deloitte', 'website_url': 'https://www.linkedin.com/company/deloitte?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C560BAQGNtpblgQpJoQ/company-logo_100_100/company-logo_100_100/0/1662120928214/deloitte_logo?e=2147483647&v=beta&t=OSF8M5LreT0Sf2F-JcNk6XMT0ArCuPfDmRR-knCC4HY'}
# ✅ Successfully inserted: Agentic AI, AI & Data Specialist Master
# Aiven https://www.linkedin.com/jobs/view/support-engineer-at-aiven-4331757296?_l=en
# {'name': 'Aiven', 'website_url': 'https://fi.linkedin.com/company/aiven?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFFDxNih2OBSw/company-logo_100_100/B56ZfA0FabGoAQ-/0/1751286569231/aiven_logo?e=2147483647&v=beta&t=9W3Io_B2OiIE9OO3hX0JP5xHub5l02GiPBDX9BBOazk'}
# ✅ Successfully inserted: Support Engineer
# AMD https://www.linkedin.com/jobs/view/sr-staff-kernel-linux-virtualization-engineer-at-amd-4306159586?_l=en
# {'name': 'AMD', 'website_url': 'https://www.linkedin.com/company/amd?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFCdxxVA_xhqQ/company-logo_100_100/B56ZnuIjafHUAU-/0/1760636844195/amd_logo?e=2147483647&v=beta&t=7sw3BjNNNSGV0P6imSg3j1KA9Z07vLBQjTYIMB-k8zI'}
# ✅ Successfully inserted: Sr. Staff - Kernel / Linux Virtualization Engineer
# AMD https://www.linkedin.com/jobs/view/network-systems-engineer-data-center-gpu-at-amd-4316710671?_l=en
# {'name': 'AMD', 'website_url': 'https://www.linkedin.com/company/amd?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFCdxxVA_xhqQ/company-logo_100_100/B56ZnuIjafHUAU-/0/1760636844195/amd_logo?e=2147483647&v=beta&t=7sw3BjNNNSGV0P6imSg3j1KA9Z07vLBQjTYIMB-k8zI'}
# ✅ Successfully inserted: Network Systems Engineer - Data Center GPU
# Amazon Web Services (AWS) https://www.linkedin.com/jobs/view/asic-design-engineer-cloud-scale-machine-learning-acceleration-team-at-amazon-web-services-aws-4298256417?_l=en
# {'name': 'Amazon Web Services (AWS)', 'website_url': 'https://www.linkedin.com/company/amazon-web-services?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQFqdm1TZ-RZKQ/company-logo_100_100/B4EZgOay6gHEAY-/0/1752588562343/amazon_web_services_logo?e=2147483647&v=beta&t=813v--p_AS7bme1J7PlAyB2BEU4-c9ba9AUzyuGb5Wg'}
# ✅ Successfully inserted: ASIC Design Engineer, Cloud-Scale Machine Learning Acceleration team
# Launch Potato https://www.linkedin.com/jobs/view/principal-ml-engineer-at-launch-potato-4333947482?_l=en
# {'name': 'Launch Potato', 'website_url': 'https://www.linkedin.com/company/launchpotato?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C4D0BAQERVR3jo_0rww/company-logo_100_100/company-logo_100_100/0/1638202768304/launchpotato_logo?e=2147483647&v=beta&t=JjAOQyZmq_JT4AyRmiJJ57iQ9bMW9m-Dll0jYIkbD-c'}
# ✅ Successfully inserted: Principal ML Engineer
# NVIDIA https://www.linkedin.com/jobs/view/senior-intellectual-property-security-engineer-at-nvidia-4210544208?_l=en
# {'name': 'NVIDIA', 'website_url': 'https://www.linkedin.com/company/nvidia?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQGV36q2EowSyw/company-logo_100_100/company-logo_100_100/0/1724881581208/nvidia_logo?e=2147483647&v=beta&t=oCxt8kGhi0AfLuVDY7D_jzkUIEe-fAV5Q5eLaRxXzOE'}
# ✅ Successfully inserted: Senior Intellectual Property Security Engineer
# AMD https://www.linkedin.com/jobs/view/firmware-engineer-at-amd-4337732933?_l=en
# {'name': 'AMD', 'website_url': 'https://www.linkedin.com/company/amd?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFCdxxVA_xhqQ/company-logo_100_100/B56ZnuIjafHUAU-/0/1760636844195/amd_logo?e=2147483647&v=beta&t=7sw3BjNNNSGV0P6imSg3j1KA9Z07vLBQjTYIMB-k8zI'}
# ✅ Successfully inserted: Firmware Engineer
# AMD https://www.linkedin.com/jobs/view/senior-gpu-ml-kernels-development-engineer-at-amd-4315985695?_l=en
# {'name': 'AMD', 'website_url': 'https://www.linkedin.com/company/amd?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQFCdxxVA_xhqQ/company-logo_100_100/B56ZnuIjafHUAU-/0/1760636844195/amd_logo?e=2147483647&v=beta&t=7sw3BjNNNSGV0P6imSg3j1KA9Z07vLBQjTYIMB-k8zI'}
# ✅ Successfully inserted: Senior GPU ML Kernels Development Engineer
# LPL Financial https://www.linkedin.com/jobs/view/sr-ai-security-engineer-at-lpl-financial-4281423984?_l=en
# {'name': 'LPL Financial', 'website_url': 'https://www.linkedin.com/company/lpl-financial?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQE1twiyoUbegA/company-logo_100_100/company-logo_100_100/0/1723408117679/lpl_financial_logo?e=2147483647&v=beta&t=KFQGpG5Dkd_7N0CMC6MX0mbCPGsZrGRxvJvS68lnYuM'}
# ✅ Successfully inserted: Sr. AI Security Engineer
# Abode Money https://www.linkedin.com/jobs/view/senior-software-engineer-at-abode-money-4336134213?_l=en
# {'name': 'Abode Money', 'website_url': 'https://www.linkedin.com/company/abode-money?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQGNoj1p-ydktA/company-logo_100_100/B56ZoSJJz3HAAQ-/0/1761240981224/abode_money_logo?e=2147483647&v=beta&t=EPMg0Wod1hbrv0pDP62gL_u5YJWUWUrNP7AZiC60ifY'}
# ✅ Successfully inserted: Senior Software Engineer
# Amazon https://www.linkedin.com/jobs/view/software-dev-engineer-intern-ai-summer-2026-amazon-devices-services-at-amazon-4334411026?_l=en
# {'name': 'Amazon', 'website_url': 'https://www.linkedin.com/company/amazon?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D560BAQGDLy4STCnHbg/company-logo_100_100/B56ZnZxDipI0AQ-/0/1760295142304/amazon_logo?e=2147483647&v=beta&t=qIUP7OofXIuuuVACb5ToeWH9PHXrPYsS8jsTZ3Q0sUg'}
# ✅ Successfully inserted: Software Dev Engineer Intern - AI (Summer 2026), Amazon Devices & Services
# Syndesus, Inc. https://www.linkedin.com/jobs/view/senior-machine-learning-engineer-at-syndesus-inc-4331443834?_l=en
# {'name': 'Syndesus, Inc.', 'website_url': 'https://ca.linkedin.com/company/syndesus-llc?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQFtumcBhS_u3g/company-logo_100_100/B4EZWLyqZBHgAQ-/0/1741807069013/syndesus_llc_logo?e=2147483647&v=beta&t=ROE8vLx84-WxyIs77405FSHsc0Me5kuUw49ybqPWX3E'}
# ✅ Successfully inserted: Senior Machine Learning Engineer
# Google https://www.linkedin.com/jobs/view/software-engineer-phd-early-career-infrastructure-2026-start-at-google-4291658114?_l=en
# {'name': 'Google', 'website_url': 'https://www.linkedin.com/company/google?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQGv3cqOuUMY7g/company-logo_100_100/B4EZmhegXHGcAU-/0/1759350753990/google_logo?e=2147483647&v=beta&t=zYekdwB_mnXarr4wa4kw8w3Jikm8YaakM5aiDyAyvP0'}
# ✅ Successfully inserted: Software Engineer, PhD, Early Career, Infrastructure, 2026 Start
# IBM https://www.linkedin.com/jobs/view/data-scientist-at-ibm-4340633840?_l=en
# {'name': 'IBM', 'website_url': 'https://www.linkedin.com/company/ibm?trk=public_jobs_topcard-org-name'}
# ✅ Successfully inserted: Data Scientist
# Launch Potato https://www.linkedin.com/jobs/view/senior-machine-learning-engineer-ad-performance-at-launch-potato-4334752412?_l=en
# {'name': 'Launch Potato', 'website_url': 'https://www.linkedin.com/company/launchpotato?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/C4D0BAQERVR3jo_0rww/company-logo_100_100/company-logo_100_100/0/1638202768304/launchpotato_logo?e=2147483647&v=beta&t=JjAOQyZmq_JT4AyRmiJJ57iQ9bMW9m-Dll0jYIkbD-c'}
# ✅ Successfully inserted: Senior Machine Learning Engineer, Ad Performance
# Amazon Web Services (AWS) https://www.linkedin.com/jobs/view/sr-quality-reliability-engineer-trainium-servers-and-systems-manufacturing-at-amazon-web-services-aws-4245236745?_l=en
# {'name': 'Amazon Web Services (AWS)', 'website_url': 'https://www.linkedin.com/company/amazon-web-services?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQFqdm1TZ-RZKQ/company-logo_100_100/B4EZgOay6gHEAY-/0/1752588562343/amazon_web_services_logo?e=2147483647&v=beta&t=813v--p_AS7bme1J7PlAyB2BEU4-c9ba9AUzyuGb5Wg'}
# ✅ Successfully inserted: Sr. Quality & Reliability Engineer, Trainium Servers and Systems Manufacturing
# Finished processing snapshot sd_mi1pde951uvf5gvv3u.
#
# --- Processing snapshot: sd_mi1ot4ry1glxeznzop ---
# Successfully downloaded sd_mi1ot4ry1glxeznzop. Parsing NDJSON...
# Successfully parsed 3 JSON objects.
# Processing 3 job records...
# Skipping record: it's an error log (bad_input)
# Oracle https://www.linkedin.com/jobs/view/principal-software-development-engineer-oci-at-oracle-4337883782?_l=en
# {'name': 'Oracle', 'website_url': 'https://www.linkedin.com/company/oracle?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQHYCgYovUuPtQ/company-logo_100_100/company-logo_100_100/0/1665755678957/oracle_logo?e=2147483647&v=beta&t=55lZDJhHdt3oPj2_gdPpymKz6Wv_9atXeO-CBFzAm6c'}
# ✅ Successfully inserted: Principal Software Development Engineer (OCI)
# Syndesus, Inc. https://www.linkedin.com/jobs/view/senior-machine-learning-engineer-at-syndesus-inc-4331443834?_l=en
# {'name': 'Syndesus, Inc.', 'website_url': 'https://ca.linkedin.com/company/syndesus-llc?trk=public_jobs_topcard-org-name', 'logo_url': 'https://media.licdn.com/dms/image/v2/D4E0BAQFtumcBhS_u3g/company-logo_100_100/B4EZWLyqZBHgAQ-/0/1741807069013/syndesus_llc_logo?e=2147483647&v=beta&t=ROE8vLx84-WxyIs77405FSHsc0Me5kuUw49ybqPWX3E'}
# ✅ Successfully inserted: Senior Machine Learning Engineer
# Finished processing snapshot sd_mi1ot4ry1glxeznzop.
#
# --- All snapshots processed. ---

# %%
import os
import pandas as pd
from supabase import create_client, Client
from dotenv import load_dotenv

# Load environment variables from your .env file
load_dotenv()

# Get your Supabase credentials
url = os.environ.get("SUPABASE_URL")
key = os.environ.get("SUPABASE_KEY")

# Check if credentials are loaded
if not url or not key:
    print("Error: SUPABASE_URL or SUPABASE_KEY not found in .env file.")
else:
    try:
        # 1. Initialize the Supabase client
        supabase: Client = create_client(url, key)
        
        print("Successfully connected to Supabase.")

        # 2. Query the 'jobs' table
        # .select('*') fetches all columns
        response = supabase.table('jobs').select('*').execute()
        
        # 3. Load the data into a pandas DataFrame
        # The actual data is in the 'data' attribute of the response
        df = pd.DataFrame(response.data)

        # 4. Print the DataFrame
        print("Successfully fetched data:")
        print(df)

    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# Successfully connected to Supabase.
# Successfully fetched data:
#                                        id                        created_at  \
# 0    34a3fefd-5ab9-4c43-8d9f-461a3880a099   2025-11-16T16:12:08.78556+00:00
# 1    83cec370-e3a9-4ccf-b414-f2a56c7d2f34  2025-11-16T16:12:08.976683+00:00
# 2    5a3cb586-e428-46e7-8212-6207bba68520  2025-11-16T16:23:23.969143+00:00
# 3    cab5b7f3-b9ac-4218-ab19-b7007da60ecf   2025-11-16T16:12:09.33026+00:00
# 4    5b9964ac-8fec-43a9-a5be-82c7341fbadc  2025-11-16T16:08:51.804495+00:00
# ..                                    ...                               ...
# 995  38e5fa43-5073-4a7a-9f2d-1c85fb3eb0fc  2025-11-16T16:15:04.666118+00:00
# 996  d70278d8-1434-4676-931c-59d4865b8c4e  2025-11-16T16:22:36.713517+00:00
# 997  ee509342-ae79-4fbe-957a-b0ec5652102e  2025-11-16T16:22:36.925887+00:00
# 998  28dfa641-e8b4-49f9-831c-2a700cdcd13b  2025-11-16T16:22:37.132213+00:00
# 999  5dddecb3-d22d-47b9-9978-3cee017b4999  2025-11-16T16:22:37.341446+00:00
#
#                                                  title  \
# 0                 Senior Software Development Engineer
# 1            Senior Software Engineer, Google Cloud AI
# 2    Senior DGX AI Cloud Performance Analysis Tools...
# 3                      Senior Digital Twin ML Engineer
# 4                                          ML Engineer
# ..                                                 ...
# 995  Member of Technical Staff, Video Generation - ...
# 996  Senior System Application Engineer – Data Cent...
# 997              Full Stack Developer (Kotlin or Java)
# 998  Machine Learning & Data Infrastructure Enginee...
# 999  Machine Learning Research Engineer (Remote | $...
#
#                                            description  \
# 0    Job Description At Oracle Cloud Infrastructure...
# 1    Minimum qualifications: Bachelor’s degree or e...
# 2    Joining NVIDIA's DGX Cloud AI Efficiency Team ...
# 3    About Grafton Sciences We’re building physical...
# 4    Our Client Is a rapidly growing Tier 1 VC back...
# ..                                                 ...
# 995  About xAI xAI’s mission is to create AI system...
# 996  WHAT YOU DO AT AMD CHANGES EVERYTHING At AMD, ...
# 997  Join the DataAnnotation team and contribute to...
# 998  Who we are: GoMaterials is one of Canada's fas...
# 999  Machine Learning Researchers Hourly Contract |...
#
#                                company_id             location_name  \
# 0    91d2954e-bd55-4b19-83dd-37508a1412c9          Redwood City, CA
# 1    8141dbf8-9017-4ddb-8329-3cdabe6912ac             Sunnyvale, CA
# 2    586f12ce-743a-461a-9ebb-275587025e5e                Austin, TX
# 3    bc253199-8947-47d2-ab0e-2f772f4006cc            Menlo Park, CA
# 4    457b8d2f-77ce-4b04-a473-28df76b5594b            Menlo Park, CA
# ..                                    ...                       ...
# 995  3089c212-8a3b-4da2-b59c-994c79301482             Palo Alto, CA
# 996  831cead0-0d4b-4547-9a02-699d5eff6d97  Markham, Ontario, Canada
# 997  536816a4-b1ba-474f-9951-8bb4b66fd7af                    Canada
# 998  ba247b42-22d6-412f-bfcb-f44e4a6d8ee4                    Canada
# 999  a8ee0e94-cabc-4ee3-9ba4-c3601bfa039f                    Canada
#
#     location_type                                          apply_url  \
# 0         On-Site  https://www.linkedin.com/signup/cold-join?sour...
# 1         On-Site  https://www.linkedin.com/jobs/view/externalApp...
# 2         On-Site  https://www.linkedin.com/jobs/view/externalApp...
# 3          Hybrid  https://www.linkedin.com/jobs/view/senior-digi...
# 4         On-Site  https://www.linkedin.com/jobs/view/ml-engineer...
# ..            ...                                                ...
# 995       On-Site  https://www.linkedin.com/jobs/view/member-of-t...
# 996       On-Site  https://www.linkedin.com/jobs/view/senior-syst...
# 997        Remote  https://www.linkedin.com/jobs/view/externalApp...
# 998       On-Site  https://www.linkedin.com/jobs/view/externalApp...
# 999        Remote  https://www.linkedin.com/signup/cold-join?sour...
#
#                          posted_at      source  ...  is_featured  user_id  \
# 0     2025-11-16T11:13:45.53+00:00  BrightData  ...        False     None
# 1    2025-11-15T14:13:45.537+00:00  BrightData  ...        False     None
# 2    2025-11-02T12:39:58.067+00:00  BrightData  ...        False     None
# 3    2025-11-14T14:13:45.611+00:00  BrightData  ...        False     None
# 4    2025-11-14T13:57:25.305+00:00  BrightData  ...        False     None
# ..                             ...         ...  ...          ...      ...
# 995  2025-11-15T14:06:46.007+00:00  BrightData  ...        False     None
# 996  2025-11-09T13:41:38.665+00:00  BrightData  ...        False     None
# 997  2025-11-09T13:41:38.693+00:00  BrightData  ...        False     None
# 998  2025-10-17T13:41:38.696+00:00  BrightData  ...        False     None
# 999  2025-11-16T11:41:38.729+00:00  BrightData  ...        False     None
#
#     employment_type salary_min  salary_max  salary_currency salary_period  \
# 0         Full-time    79800.0    178100.0                $            yr
# 1         Full-time   166000.0    244000.0                $            yr
# 2         Full-time   184000.0    356500.0                $            yr
# 3         Full-time        NaN         NaN             None          None
# 4         Full-time        NaN         NaN             None          None
# ..              ...        ...         ...              ...           ...
# 995       Full-time   180000.0    440000.0                $            yr
# 996       Full-time   146800.0    220200.0                $            yr
# 997       Full-time        NaN         NaN             None          None
# 998       Full-time        NaN         NaN             None          None
# 999       Part-time      120.0       120.0                $            hr
#
#      city state country
# 0    None  None    None
# 1    None  None    None
# 2    None  None    None
# 3    None  None    None
# 4    None  None    None
# ..    ...   ...     ...
# 995  None  None    None
# 996  None  None    None
# 997  None  None    None
# 998  None  None    None
# 999  None  None    None
#
# [1000 rows x 21 columns]

# %%
df['location_name'].unique()
# Out:
# array(['Redwood City, CA', 'Sunnyvale, CA', 'Austin, TX',
#        'Menlo Park, CA', 'Palo Alto, CA', 'San Francisco Bay Area',
#        'San Jose, CA', 'Santa Clara, CA', 'Foster City, CA',
#        'Mountain View, CA', 'Cupertino, CA', 'Fremont, CA',
#        'Silicon Valley, CA', 'San Mateo, CA', 'Milpitas, CA',
#        'Toronto, Ontario, Canada', 'Halifax, Nova Scotia, Canada',
#        'Victoria, Nova Scotia, Canada', 'Markham, Ontario, Canada',
#        'Canada', 'Vancouver, British Columbia, Canada',
#        'Saskatoon, Saskatchewan, Canada', 'Etobicoke, Ontario, Canada',
#        'Waterloo, Ontario, Canada', 'Dublin, CA',
#        'Montreal, Quebec, Canada', 'Pleasanton, CA',
#        'Greater Toronto Area, Canada', 'Ontario, Canada',
#        'Gatineau, Quebec, Canada', 'Hamilton, Ontario, Canada',
#        'Calgary, Alberta, Canada', 'Mississauga, Ontario, Canada',
#        'Brantford, Ontario, Canada', 'Greater Ottawa Metropolitan Area',
#        'Ottawa, Ontario, Canada', 'London, Canada Metropolitan Area',
#        'San Carlos, CA', 'British Columbia, Canada', 'Los Altos, CA',
#        'Stanford, CA', 'Round Rock, TX',
#        'Greater Montreal Metropolitan Area',
#        'Burnaby, British Columbia, Canada', 'Santa Clara County, CA',
#        'San Francisco, CA', 'Greater Vancouver, British Columbia, Canada',
#        'Kings, Subdivision C, Nova Scotia, Canada',
#        'Greater Halifax Metropolitan Area',
#        'Greater Vancouver Metropolitan Area',
#        'North York, Ontario, Canada', 'Kanata, Ontario, Canada',
#        'Dieppe, New Brunswick, Canada',
#        'St John’s, Newfoundland and Labrador, Canada',
#        'Victoria, British Columbia, Canada', 'Edmonton, Alberta, Canada',
#        'Brampton, Ontario, Canada', 'Winnipeg, Manitoba, Canada',
#        'Austin, Texas Metropolitan Area', 'Vaughan, Ontario, Canada',
#        'Laval, Quebec, Canada'], dtype=object)

# %%
# --- 3. FETCH DATA AND PROCESS IT ---

try:
    print("Fetching all jobs from database (handling pagination)...")
    
    all_jobs = []
    page_size = 1000
    page = 0
    
    while True:
        start_index = page * page_size
        end_index = start_index + page_size - 1
        
        # Fetch a "page" of data using .range()
        # We select only the columns we need: id and location_name
        response = supabase.table('jobs').select('id, location_name').range(start_index, end_index).execute()
        
        data = response.data
        all_jobs.extend(data)
        
        print(f"Fetched {len(data)} records (page {page + 1})...")
        
        # If we fetched fewer records than the page size, 
        # it means we've reached the end.
        if len(data) < page_size:
            break
            
        page += 1
        # Add a small delay to be kind to the API
        # time.sleep(0.1) 

    df = pd.DataFrame(all_jobs)

    if df.empty:
        print("No job data found.")
    else:
        print(f"\nSuccessfully fetched a total of {len(df)} job records.")
        
        # Apply the parser function to the 'location_name' column
        # and create new columns from the result
        parsed_data = df['location_name'].apply(parse_location)
        df_parsed = pd.json_normalize(parsed_data)
        
        # Combine the new columns with the original DataFrame
        df = df.join(df_parsed)

        # Display the results for verification
        print("\n--- Parsing Results (Sample) ---")
        print(df.head(20)) # Show a sample of the parsed data
        
        # Show all unique new locations for review
        print("\n--- Unique Parsed Locations ---")
        print(df.drop_duplicates(subset=['city', 'state', 'country'])[['location_name', 'city', 'state', 'country']])


        # --- 4. UPDATE THE DATABASE (Run this part when ready) ---
        
        # This section is commented out to prevent accidental writes.
        # Review the output above first. If it looks correct,
        # uncomment the code below and re-run the cell.

        print("\n--- Starting Database Update ---")
        update_count = 0
        
        # Convert DataFrame to a list of dictionaries for the update
        # We only need rows where data actually changed or is new
        updates_to_send = df.where(pd.notnull(df), None).to_dict('records')

        for row in updates_to_send:
            try:
                # Create the payload to send
                update_payload = {
                    'city': row['city'],
                    'state': row['state'],
                    'country': row['country']
                }
                
                # Perform the update
                supabase.table('jobs').update(update_payload).eq('id', row['id']).execute()
                
                update_count += 1
                if update_count % 50 == 0: # Print progress
                    print(f"Updated {update_count} records...")

            except Exception as e:
                print(f"Error updating job {row['id']}: {e}")

        print(f"\n--- Update Complete: {update_count} job records updated. ---")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Fetching all jobs from database (handling pagination)...
# Fetched 1000 records (page 1)...
# Fetched 1000 records (page 2)...
# Fetched 862 records (page 3)...
#
# Successfully fetched a total of 2862 job records.
#
# --- Parsing Results (Sample) ---
#                                       id           location_name  \
# 0   34a3fefd-5ab9-4c43-8d9f-461a3880a099        Redwood City, CA
# 1   83cec370-e3a9-4ccf-b414-f2a56c7d2f34           Sunnyvale, CA
# 2   5a3cb586-e428-46e7-8212-6207bba68520              Austin, TX
# 3   cab5b7f3-b9ac-4218-ab19-b7007da60ecf          Menlo Park, CA
# 4   5b9964ac-8fec-43a9-a5be-82c7341fbadc          Menlo Park, CA
# 5   da5141a3-4434-455f-8746-5f92da568397           Palo Alto, CA
# 6   f1aca45c-9f03-46ec-aa4d-3820dd5822bd  San Francisco Bay Area
# 7   8554b51f-67fd-41db-b6e6-b36d684c8090            San Jose, CA
# 8   1401ff23-d84c-427d-ba4b-5a048ab6a929         Santa Clara, CA
# 9   0d8829c3-724d-40a6-9c4e-a8cc35e6f450            San Jose, CA
# 10  ca55637d-7540-42d3-8125-2f34b4c35988         Foster City, CA
# 11  816f24f9-fab6-43c5-9f45-eb1d3d45e1af            San Jose, CA
# 12  f2cb2679-e309-4eb0-9d1e-503be363416b         Santa Clara, CA
# 13  0361c8ef-ee09-4e43-9c8e-25f841d87565       Mountain View, CA
# 14  dc5d70b6-9ac6-44a3-9bd3-26a75fc46a60           Sunnyvale, CA
# 15  452f2015-84a3-49ef-93c7-0787fe62f1a7            San Jose, CA
# 16  dd0212aa-6abf-4f83-8a42-5ebd64ded041            San Jose, CA
# 17  8d22dddf-d34c-4e30-9df4-7e19fc4979a7          Menlo Park, CA
# 18  288e2035-e05a-46a1-aa2f-80403ad64fcf              Austin, TX
# 19  3f0b4e82-79c4-46e0-ac01-6851750825bd           Palo Alto, CA
#
#                       city state country
# 0             Redwood City    CA     USA
# 1                Sunnyvale    CA     USA
# 2                   Austin    TX     USA
# 3               Menlo Park    CA     USA
# 4               Menlo Park    CA     USA
# 5                Palo Alto    CA     USA
# 6   San Francisco Bay Area    CA     USA
# 7                 San Jose    CA     USA
# 8              Santa Clara    CA     USA
# 9                 San Jose    CA     USA
# 10             Foster City    CA     USA
# 11                San Jose    CA     USA
# 12             Santa Clara    CA     USA
# 13           Mountain View    CA     USA
# 14               Sunnyvale    CA     USA
# 15                San Jose    CA     USA
# 16                San Jose    CA     USA
# 17              Menlo Park    CA     USA
# 18                  Austin    TX     USA
# 19               Palo Alto    CA     USA
#
# --- Unique Parsed Locations ---
#                    location_name          city    state country
# 0               Redwood City, CA  Redwood City       CA     USA
# 1                  Sunnyvale, CA     Sunnyvale       CA     USA
# 2                     Austin, TX        Austin       TX     USA
# 3                 Menlo Park, CA    Menlo Park       CA     USA
# 5                  Palo Alto, CA     Palo Alto       CA     USA
# ...                          ...           ...      ...     ...
# 2282  Kitchener, Ontario, Canada     Kitchener  Ontario  Canada
# 2283   Kingston, Ontario, Canada      Kingston  Ontario  Canada
# 2299      Dorval, Quebec, Canada        Dorval   Quebec  Canada
# 2523              Cedar Park, TX    Cedar Park       TX     USA
# 2545                 Leander, TX       Leander       TX     USA
#
# [93 rows x 4 columns]
#
# --- Starting Database Update ---
# Updated 50 records...
# Updated 100 records...
# Updated 150 records...
# Updated 200 records...
# Updated 250 records...
# Updated 300 records...
# Updated 350 records...
# Updated 400 records...
# Updated 450 records...
# Updated 500 records...
# Updated 550 records...
# Updated 600 records...
# Updated 650 records...
# Updated 700 records...
# Updated 750 records...
# Updated 800 records...
# Updated 850 records...
# Updated 900 records...
# Updated 950 records...
# Updated 1000 records...
# Updated 1050 records...
# Updated 1100 records...
# Updated 1150 records...
# Updated 1200 records...
# Updated 1250 records...
# Updated 1300 records...
# Updated 1350 records...
# Updated 1400 records...
# Updated 1450 records...
# Updated 1500 records...
# Updated 1550 records...
# Updated 1600 records...
# Updated 1650 records...
# Updated 1700 records...
# Updated 1750 records...
# Updated 1800 records...
# Updated 1850 records...
# Updated 1900 records...
# Updated 1950 records...
# Updated 2000 records...
# Updated 2050 records...
# Updated 2100 records...
# Updated 2150 records...
# Updated 2200 records...
# Updated 2250 records...
# Updated 2300 records...
# Updated 2350 records...
# Updated 2400 records...
# Updated 2450 records...
# Updated 2500 records...
# Updated 2550 records...
# Updated 2600 records...
# Updated 2650 records...
# Updated 2700 records...
# Updated 2750 records...
# Updated 2800 records...
# Updated 2850 records...
#
# --- Update Complete: 2862 job records updated. ---

# %%
# --- SETUP (Ensure your supabase client is initialized as before) ---
import os
from supabase import create_client, Client
url: str = os.environ.get("SUPABASE_URL")
key: str = os.environ.get("SUPABASE_KEY")
supabase: Client = create_client(url, key)

try:
    print("--- Starting Correction of State Names ---")

    # 1. Correct California (CA -> California)
    print("Converting 'CA' to 'California'...")
    response_ca = supabase.table('jobs') \
        .update({'state': 'California'}) \
        .eq('state', 'CA') \
        .execute()
    
    # Count how many were fixed
    count_ca = len(response_ca.data) if response_ca.data else 0
    print(f"✅ Successfully updated {count_ca} records from 'CA' to 'California'.")

    # 2. Correct Texas (TX -> Texas)
    print("Converting 'TX' to 'Texas'...")
    response_tx = supabase.table('jobs') \
        .update({'state': 'Texas'}) \
        .eq('state', 'TX') \
        .execute()

    # Count how many were fixed
    count_tx = len(response_tx.data) if response_tx.data else 0
    print(f"✅ Successfully updated {count_tx} records from 'TX' to 'Texas'.")

    print("\n--- Correction Complete ---")
    print(f"Total records updated: {count_ca + count_tx}")

except Exception as e:
    print(f"An error occurred during the update: {e}")
# Out:
# --- Starting Correction of State Names ---
# Converting 'CA' to 'California'...
# ✅ Successfully updated 1427 records from 'CA' to 'California'.
# Converting 'TX' to 'Texas'...
# ✅ Successfully updated 515 records from 'TX' to 'Texas'.
#
# --- Correction Complete ---
# Total records updated: 1942
